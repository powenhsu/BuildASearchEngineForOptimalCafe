# %% [markdown]
# # **Daily Grind App - Joy, Joy, Elina, Meenu, Po Wen**

# %% [markdown]
# **Collect and PreProcesss the Data**

# %%
#pip in the google maps API
# !pip install googlemaps
# Out:
# Requirement already satisfied: googlemaps in /Users/PinkyPig/opt/anaconda3/lib/python3.9/site-packages (4.10.0)
# Requirement already satisfied: requests<3.0,>=2.20.0 in /Users/PinkyPig/opt/anaconda3/lib/python3.9/site-packages (from googlemaps) (2.28.1)
# Requirement already satisfied: charset-normalizer<3,>=2 in /Users/PinkyPig/opt/anaconda3/lib/python3.9/site-packages (from requests<3.0,>=2.20.0->googlemaps) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/PinkyPig/opt/anaconda3/lib/python3.9/site-packages (from requests<3.0,>=2.20.0->googlemaps) (2022.9.24)
# Requirement already satisfied: idna<4,>=2.5 in /Users/PinkyPig/opt/anaconda3/lib/python3.9/site-packages (from requests<3.0,>=2.20.0->googlemaps) (3.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/PinkyPig/opt/anaconda3/lib/python3.9/site-packages (from requests<3.0,>=2.20.0->googlemaps) (1.26.11)

# %%
# collect 20 cafes from the 10 locations we have set in Manhattan
# Upper West Side 20 cafes
import googlemaps
from datetime import datetime

# Set up the Google Maps API client
gmaps = googlemaps.Client(key='AIzaSyAa81xKqSxG-Rh83POFL8Y-TcdXaLGi27k')

location = "40.7870, -73.9754"

# Set up the search parameters
uws_params = {
    'location': location,
    'radius': 300,
    'type': 'cafe'
}

# Use the Places API to search for cafes near the location
uws_results = gmaps.places_nearby(**uws_params)

#Print the name, address, and amenities of each cafe
for place in uws_results['results']:
    print(place['name'])
    if 'types' in place:
        print('Amenities:', ', '.join(place['types']))
    if 'opening_hours' in place:
        print('Open:', ', '.join(place['opening_hours']))
    print()
# Out:
# Cafe Lalo
# Amenities: cafe, food, point_of_interest, establishment
#
# Barnes & Noble
# Amenities: book_store, cafe, store, food, point_of_interest, establishment
# Open: open_now
#
# Peacefood Uptown
# Amenities: cafe, bakery, store, restaurant, food, point_of_interest, establishment
# Open: open_now
#
# French Roast
# Amenities: cafe, store, restaurant, food, point_of_interest, establishment
# Open: open_now
#
# Starbucks
# Amenities: cafe, store, restaurant, food, point_of_interest, establishment
# Open: open_now
#
# Joe Coffee Company
# Amenities: cafe, store, food, point_of_interest, establishment
# Open: open_now
#
# Starbucks
# Amenities: cafe, store, restaurant, food, point_of_interest, establishment
# Open: open_now
#
# Matto Espresso
# Amenities: cafe, store, food, point_of_interest, establishment
# Open: open_now
#
# Flowers On The Park
# Amenities: florist, cafe, store, food, point_of_interest, establishment
# Open: open_now
#
# Uptown Poké
# Amenities: cafe, restaurant, food, point_of_interest, establishment
# Open: open_now
#
# Dunkin'
# Amenities: meal_takeaway, cafe, bakery, store, restaurant, food, point_of_interest, establishment
# Open: open_now
#
# Hawa Smoothies & Bubble Tea
# Amenities: cafe, restaurant, food, point_of_interest, establishment
# Open: open_now
#
# Grain of rice
# Amenities: cafe, food, point_of_interest, establishment
#
# Amsterdam Cafe
# Amenities: cafe, meal_takeaway, store, restaurant, food, point_of_interest, establishment
# Open: open_now
#
# Blank Street Coffee
# Amenities: cafe, bakery, store, food, point_of_interest, establishment
# Open: open_now
#
# Crossbar
# Amenities: restaurant, cafe, bakery, store, food, point_of_interest, establishment
# Open: open_now
#
# Chalait UWS
# Amenities: cafe, store, food, point_of_interest, establishment
# Open: open_now
#
# Barachou Upper West Side
# Amenities: bakery, cafe, store, food, point_of_interest, establishment
# Open: open_now

# %%
# collect 20 cafes from the 10 locations we have set in Manhattan
# midtown 20 cafes
import googlemaps
from datetime import datetime

# Set up the Google Maps API client
gmaps = googlemaps.Client(key='AIzaSyAa81xKqSxG-Rh83POFL8Y-TcdXaLGi27k')

location = "40.7549, -73.9840"

# Set up the search parameters
midtown_params = {
    'location': location,
    'radius': 300,
    'type': 'cafe'
}

# Use the Places API to search for cafes near the location
midtown_results = gmaps.places_nearby(**midtown_params)

#Print the name, address, and amenities of each cafe
for place in midtown_results['results']:
    print(place['name'])
    if 'types' in place:
        print('Amenities:', ', '.join(place['types']))
    if 'opening_hours' in place:
        print('Open:', ', '.join(place['opening_hours']))
    print()
# Out:
# The Red Flame
# Amenities: cafe, meal_takeaway, restaurant, food, point_of_interest, store, establishment
# Open: open_now
#
# Gregorys Coffee
# Amenities: cafe, food, point_of_interest, store, establishment
# Open: open_now
#
# Lady M Cake Boutique - New York City
# Amenities: bakery, cafe, food, point_of_interest, store, establishment
# Open: open_now
#
# Starbucks
# Amenities: cafe, restaurant, food, point_of_interest, store, establishment
# Open: open_now
#
# Venice Simplon Orient Espress
# Amenities: cafe, food, point_of_interest, store, establishment
# Open: open_now
#
# Breads Bakery
# Amenities: bakery, cafe, food, point_of_interest, store, establishment
# Open: open_now
#
# Wafels & Dinges
# Amenities: cafe, restaurant, food, point_of_interest, store, establishment
# Open: open_now
#
# Joe & The Juice
# Amenities: cafe, meal_takeaway, restaurant, food, point_of_interest, store, establishment
# Open: open_now
#
# Joe Coffee Company
# Amenities: cafe, food, point_of_interest, store, establishment
# Open: open_now
#
# Bryant Park Café
# Amenities: bar, cafe, restaurant, food, point_of_interest, establishment
# Open: open_now
#
# La Colombe Coffee Roasters
# Amenities: cafe, food, point_of_interest, store, establishment
# Open: open_now
#
# Starbucks
# Amenities: cafe, restaurant, food, point_of_interest, store, establishment
# Open: open_now
#
# Starbucks
# Amenities: cafe, restaurant, food, point_of_interest, store, establishment
# Open: open_now
#
# Dunkin'
# Amenities: bakery, cafe, meal_takeaway, restaurant, food, point_of_interest, store, establishment
# Open: open_now
#
# Dunkin'
# Amenities: bakery, cafe, meal_takeaway, restaurant, food, point_of_interest, store, establishment
# Open: open_now
#
# EspressoWorks
# Amenities: cafe, food, point_of_interest, establishment
# Open: open_now
#
# Pret A Manger
# Amenities: cafe, meal_takeaway, restaurant, food, point_of_interest, store, establishment
# Open: open_now
#
# Starbucks
# Amenities: cafe, restaurant, food, point_of_interest, store, establishment
# Open: open_now
#
# News Agency
# Amenities: cafe, food, point_of_interest, store, establishment
# Open: open_now
#
# Bluestone Lane Bryant Park Coffee Shop
# Amenities: cafe, bar, food, point_of_interest, store, establishment
# Open: open_now

# %%
# collect 20 cafes from the 10 locations we have set in Manhattan
# Hell's Kitchen 20 cafes
import googlemaps
from datetime import datetime

# Set up the Google Maps API client
gmaps = googlemaps.Client(key='AIzaSyAa81xKqSxG-Rh83POFL8Y-TcdXaLGi27k')

location = "40.763, -73.992"

# Set up the search parameters
hellskitchen_params = {
    'location': location,
    'radius': 300,
    'type': 'cafe'
}

# Use the Places API to search for cafes near the location
hellskitchen_results = gmaps.places_nearby(**hellskitchen_params)

#Print the name, address, and amenities of each cafe
for place in hellskitchen_results['results']:
    print(place['name'])
    if 'types' in place:
        print('Amenities:', ', '.join(place['types']))
    if 'opening_hours' in place:
        print('Open:', ', '.join(place['opening_hours']))
    print()
# Out:
# Amish Market
# Amenities: supermarket, cafe, bakery, meal_takeaway, grocery_or_supermarket, store, restaurant, food, point_of_interest, establishment
# Open: open_now
#
# The Jolly Goat Coffee Bar
# Amenities: cafe, store, food, point_of_interest, establishment
# Open: open_now
#
# Vintner Market (Beer Cheese)
# Amenities: liquor_store, cafe, bar, store, food, point_of_interest, establishment
# Open: open_now
#
# Seasonal Grounds
# Amenities: cafe, food, point_of_interest, establishment
#
# Dunkin'
# Amenities: cafe, bakery, meal_takeaway, store, restaurant, food, point_of_interest, establishment
# Open: open_now
#
# ESCO CAFÉ
# Amenities: cafe, food, point_of_interest, establishment
# Open: open_now
#
# Her Boba
# Amenities: cafe, store, restaurant, food, point_of_interest, establishment
# Open: open_now
#
# JOOY TEA SHOPPE
# Amenities: cafe, food, point_of_interest, establishment
# Open: open_now
#
# UT47 Manhattan
# Amenities: cafe, bakery, bar, store, restaurant, food, point_of_interest, establishment
# Open: open_now
#
# CoCo Fresh Tea & Juice
# Amenities: cafe, food, point_of_interest, establishment
# Open: open_now
#
# Matto Espresso
# Amenities: cafe, food, point_of_interest, establishment

# %%
# collect 20 cafes from the 10 locations we have set in Manhattan
# Upper East Side 20 cafes
import googlemaps
from datetime import datetime

# Set up the Google Maps API client
gmaps = googlemaps.Client(key='AIzaSyAa81xKqSxG-Rh83POFL8Y-TcdXaLGi27k')

location = "40.7736, -73.9566"

# Set up the search parameters
ues_params = {
    'location': location,
    'radius': 300,
    'type': 'cafe'
}

# Use the Places API to search for cafes near the location
ues_results = gmaps.places_nearby(**ues_params)

#Print the name, address, and amenities of each cafe
for place in ues_results['results']:
    print(place['name'])
    if 'types' in place:
        print('Amenities:', ', '.join(place['types']))
    if 'opening_hours' in place:
        print('Open:', ', '.join(place['opening_hours']))
    print()
# Out:
# Orwashers Bakery
# Amenities: bakery, cafe, food, store, point_of_interest, establishment
# Open: open_now
#
# Starbucks
# Amenities: cafe, restaurant, food, store, point_of_interest, establishment
# Open: open_now
#
# Antonucci Cafe
# Amenities: cafe, bar, restaurant, food, point_of_interest, establishment
# Open: open_now
#
# Starbucks
# Amenities: cafe, restaurant, food, store, point_of_interest, establishment
# Open: open_now
#
# Hutch and Waldo Upper East
# Amenities: cafe, bakery, restaurant, food, store, point_of_interest, establishment
# Open: open_now
#
# Starbucks
# Amenities: cafe, restaurant, food, store, point_of_interest, establishment
# Open: open_now
#
# Cafe Noi
# Amenities: cafe, bakery, food, store, point_of_interest, establishment
#
# 787 Coffee
# Amenities: cafe, bakery, restaurant, food, store, point_of_interest, establishment
# Open: open_now
#
# Birdbath Bakery JUICE
# Amenities: bakery, cafe, food, store, point_of_interest, establishment
#
# Tozzo The Italian Coffee Shop
# Amenities: cafe, food, store, point_of_interest, establishment
# Open: open_now
#
# Innocent Yesterday
# Amenities: cafe, bakery, food, store, point_of_interest, establishment
# Open: open_now
#
# OLLIE’S TO GO - UES
# Amenities: cafe, meal_delivery, meal_takeaway, restaurant, food, point_of_interest, establishment
# Open: open_now
#
# Maman
# Amenities: cafe, bakery, restaurant, food, store, point_of_interest, establishment
# Open: open_now
#
# Ella's Cafe Espresso & Wine Bar
# Amenities: cafe, food, store, point_of_interest, establishment
# Open: open_now
#
# Angelina Paris Lexington
# Amenities: cafe, food, store, point_of_interest, establishment
# Open: open_now
#
# Handcraft Coffee
# Amenities: cafe, food, store, point_of_interest, establishment
# Open: open_now
#
# coffee gear
# Amenities: cafe, food, store, point_of_interest, establishment
#
# Matto Espresso
# Amenities: cafe, food, store, point_of_interest, establishment
# Open: open_now
#
# Blank Street Coffee
# Amenities: cafe, bakery, food, store, point_of_interest, establishment
# Open: open_now
#
# Dunkin'
# Amenities: cafe, bakery, meal_takeaway, restaurant, food, store, point_of_interest, establishment
# Open: open_now

# %%
# collect 20 cafes from the 10 locations we have set in Manhattan
# Chelsea 20 cafes
import googlemaps
from datetime import datetime

# Set up the Google Maps API client
gmaps = googlemaps.Client(key='AIzaSyAa81xKqSxG-Rh83POFL8Y-TcdXaLGi27k')

location = "40.7465, -74.0014"

# Set up the search parameters
chelsea_params = {
    'location': location,
    'radius': 300,
    'type': 'cafe'
}

# Use the Places API to search for cafes near the location
chelsea_results = gmaps.places_nearby(**chelsea_params)

#Print the name, address, and amenities of each cafe
for place in chelsea_results['results']:
    print(place['name'])
    if 'types' in place:
        print('Amenities:', ', '.join(place['types']))
    if 'opening_hours' in place:
        print('Open:', ', '.join(place['opening_hours']))
    print()
# Out:
# Joe Coffee Company
# Amenities: cafe, food, store, point_of_interest, establishment
# Open: open_now
#
# Starbucks
# Amenities: cafe, restaurant, food, store, point_of_interest, establishment
# Open: open_now
#
# Sullivan Street Bakery and Pizza
# Amenities: bakery, cafe, restaurant, food, store, point_of_interest, establishment
# Open: open_now
#
# Chelsea Pantry Cafe
# Amenities: cafe, food, point_of_interest, establishment
# Open: open_now
#
# HARBS Chelsea
# Amenities: cafe, bakery, food, store, point_of_interest, establishment
# Open: open_now
#
# Dunkin'
# Amenities: meal_takeaway, bakery, cafe, restaurant, food, store, point_of_interest, establishment
# Open: open_now
#
# Blank Street Coffee
# Amenities: bakery, cafe, food, store, point_of_interest, establishment
# Open: open_now
#
# Dunkin'
# Amenities: meal_takeaway, bakery, cafe, restaurant, food, store, point_of_interest, establishment
# Open: open_now
#
# Café Moore
# Amenities: cafe, food, point_of_interest, establishment
# Open: open_now
#
# The Moore
# Amenities: cafe, lodging, bar, food, store, point_of_interest, establishment
#
# Hawa Smoothies & Bubble Tea
# Amenities: cafe, health, food, store, point_of_interest, establishment
# Open: open_now
#
# HOUSE of WARIS Botanicals
# Amenities: cafe, food, store, point_of_interest, establishment
#
# Big Cup
# Amenities: cafe, food, point_of_interest, establishment

# %%
# collect 20 cafes from the 10 locations we have set in Manhattan
# Soho 20 cafes
import googlemaps
from datetime import datetime

# Set up the Google Maps API client
gmaps = googlemaps.Client(key='AIzaSyAa81xKqSxG-Rh83POFL8Y-TcdXaLGi27k')

location = "40.7242, -74.0024"

# Set up the search parameters
soho_params = {
    'location': location,
    'radius': 300,
    'type': 'cafe'
}

# Use the Places API to search for cafes near the location
soho_results = gmaps.places_nearby(**soho_params)

#Print the name, address, and amenities of each cafe
for place in soho_results['results']:
    print(place['name'])
    if 'types' in place:
        print('Amenities:', ', '.join(place['types']))
    if 'opening_hours' in place:
        print('Open:', ', '.join(place['opening_hours']))
    print()
# Out:
# Dominique Ansel Bakery
# Amenities: bakery, cafe, store, food, point_of_interest, establishment
# Open: open_now
#
# Ground Support Cafe
# Amenities: cafe, store, food, point_of_interest, establishment
# Open: open_now
#
# La Colombe Coffee Roasters
# Amenities: cafe, store, food, point_of_interest, establishment
# Open: open_now
#
# L.A. Burdick Handmade Chocolates
# Amenities: cafe, store, food, point_of_interest, establishment
# Open: open_now
#
# Rapha New York
# Amenities: clothing_store, cafe, bicycle_store, store, food, point_of_interest, establishment
# Open: open_now
#
# JOE & THE JUICE
# Amenities: meal_takeaway, cafe, store, restaurant, food, point_of_interest, establishment
# Open: open_now
#
# Chobani SoHo
# Amenities: cafe, store, restaurant, food, point_of_interest, establishment
# Open: open_now
#
# Café OLED
# Amenities: cafe, food, point_of_interest, establishment
# Open: open_now
#
# 787 Coffee
# Amenities: cafe, store, food, point_of_interest, establishment
# Open: open_now
#
# Thompson Square Studios
# Amenities: cafe, bar, restaurant, food, point_of_interest, establishment
# Open: open_now
#
# MAKEDA NY
# Amenities: cafe, clothing_store, store, food, point_of_interest, establishment
#
# Dr Smood
# Amenities: cafe, store, restaurant, food, point_of_interest, health, establishment
# Open: open_now
#
# Old Fashion Café
# Amenities: restaurant, cafe, bar, food, point_of_interest, establishment
# Open: open_now
#
# Drip Drop Café, coffee shop
# Amenities: art_gallery, cafe, store, restaurant, food, point_of_interest, establishment
# Open: open_now
#
# YUBU SoHo
# Amenities: cafe, store, restaurant, food, point_of_interest, establishment
# Open: open_now
#
# Sui Yoga & Café
# Amenities: cafe, gym, store, food, point_of_interest, health, establishment
# Open: open_now
#
# NowHere
# Amenities: art_gallery, cafe, food, point_of_interest, establishment
# Open: open_now
#
# Crispy Heaven
# Amenities: bakery, cafe, bar, store, restaurant, food, point_of_interest, establishment
# Open: open_now
#
# Ademi Coffee and Tea
# Amenities: cafe, bakery, store, restaurant, food, point_of_interest, establishment
# Open: open_now
#
# Matchaful
# Amenities: cafe, food, point_of_interest, establishment
# Open: open_now

# %%
# collect 20 cafes from the 10 locations we have set in Manhattan
# Chinatown 20 cafes
import googlemaps
from datetime import datetime

# Set up the Google Maps API client
gmaps = googlemaps.Client(key='AIzaSyAa81xKqSxG-Rh83POFL8Y-TcdXaLGi27k')

location = "40.7158, -73.9970"

# Set up the search parameters
ct_params = {
    'location': location,
    'radius': 300,
    'type': 'cafe'
}

# Use the Places API to search for cafes near the location
ct_results = gmaps.places_nearby(**ct_params)

#Print the name, address, and amenities of each cafe
for place in ct_results['results']:
    print(place['name'])
    if 'types' in place:
        print('Amenities:', ', '.join(place['types']))
    if 'opening_hours' in place:
        print('Open:', ', '.join(place['opening_hours']))
    print()
# Out:
# Golden Unicorn
# Amenities: cafe, bar, restaurant, point_of_interest, food, establishment
# Open: open_now
#
# Nom Wah Tea Parlor
# Amenities: cafe, restaurant, point_of_interest, food, establishment
# Open: open_now
#
# Elevate
# Amenities: cafe, bar, restaurant, point_of_interest, food, establishment
# Open: open_now
#
# ViVi Bubble Tea
# Amenities: cafe, point_of_interest, food, establishment
# Open: open_now
#
# Yaya Tea
# Amenities: cafe, grocery_or_supermarket, restaurant, point_of_interest, food, store, establishment
# Open: open_now
#
# La Bella Ferrara
# Amenities: bakery, cafe, point_of_interest, food, store, establishment
#
# Cha Chan Tang
# Amenities: cafe, restaurant, point_of_interest, food, establishment
# Open: open_now
#
# Sweet Moment
# Amenities: cafe, bakery, restaurant, point_of_interest, food, store, establishment
# Open: open_now
#
# Ten Ren's Tea Time
# Amenities: cafe, restaurant, point_of_interest, food, establishment
# Open: open_now
#
# Kung Fu Tea
# Amenities: cafe, restaurant, point_of_interest, food, establishment
# Open: open_now
#
# Silk Road Cafe
# Amenities: cafe, point_of_interest, food, establishment
# Open: open_now
#
# Caffe Napoli
# Amenities: cafe, bar, restaurant, point_of_interest, food, establishment
# Open: open_now
#
# Teado Tea Shop
# Amenities: cafe, point_of_interest, food, establishment
# Open: open_now
#
# Audrey Bakery and Cafe Inc
# Amenities: bakery, cafe, point_of_interest, food, store, establishment
# Open: open_now
#
# Bake Culture
# Amenities: bakery, cafe, point_of_interest, food, store, establishment
# Open: open_now
#
# Chun Yang Tea
# Amenities: cafe, point_of_interest, food, establishment
# Open: open_now
#
# Kore Coffee
# Amenities: cafe, point_of_interest, food, store, establishment
# Open: open_now
#
# Karen Rutledge
# Amenities: cafe, point_of_interest, food, establishment
#
# M Tea Chinatown
# Amenities: cafe, point_of_interest, food, establishment
#
# Gong Cha
# Amenities: cafe, point_of_interest, food, establishment
# Open: open_now

# %%
# collect 20 cafes from the 10 locations we have set in Manhattan
# East Villiage 20 cafes
import googlemaps
from datetime import datetime

# Set up the Google Maps API client
gmaps = googlemaps.Client(key='AIzaSyAa81xKqSxG-Rh83POFL8Y-TcdXaLGi27k')

location = "40.7268, -73.9815"

# Set up the search parameters
ev_params = {
    'location': location,
    'radius': 300,
    'type': 'cafe'
}

# Use the Places API to search for cafes near the location
ev_results = gmaps.places_nearby(**ev_params)

#Print the name, address, and amenities of each cafe
for place in ev_results['results']:
    print(place['name'])
    if 'types' in place:
        print('Amenities:', ', '.join(place['types']))
    if 'opening_hours' in place:
        print('Open:', ', '.join(place['opening_hours']))
    print()
# Out:
# Gnocco
# Amenities: cafe, bar, restaurant, food, store, point_of_interest, establishment
# Open: open_now
#
# Gruppo NYC Thin Crust Pizza
# Amenities: cafe, bar, meal_delivery, meal_takeaway, restaurant, food, point_of_interest, establishment
# Open: open_now
#
# Starbucks
# Amenities: cafe, restaurant, food, store, point_of_interest, establishment
# Open: open_now
#
# Ninth Street Espresso
# Amenities: cafe, food, store, point_of_interest, establishment
# Open: open_now
#
# Ray's Candy Store
# Amenities: cafe, restaurant, food, store, point_of_interest, establishment
# Open: open_now
#
# Village creperie
# Amenities: cafe, restaurant, food, store, point_of_interest, establishment
# Open: open_now
#
# Blank Street Coffee
# Amenities: cafe, bakery, food, store, point_of_interest, establishment
# Open: open_now
#
# Murphy’s
# Amenities: cafe, restaurant, food, point_of_interest, establishment
# Open: open_now
#
# La Fleur Café
# Amenities: cafe, food, health, point_of_interest, establishment
# Open: open_now
#
# Hekate Café & Elixir Lounge
# Amenities: cafe, food, store, point_of_interest, establishment
# Open: open_now
#
# C&B
# Amenities: cafe, food, point_of_interest, establishment
# Open: open_now
#
# 787 Coffee
# Amenities: cafe, food, store, point_of_interest, establishment
# Open: open_now
#
# Hi-Note
# Amenities: bar, cafe, food, store, point_of_interest, establishment
# Open: open_now
#
# Thayer
# Amenities: cafe, food, point_of_interest, establishment
# Open: open_now
#
# Kavasutra Kava Bar - 10th St
# Amenities: night_club, cafe, bar, food, store, point_of_interest, establishment
# Open: open_now
#
# All The Kings Horses Cafe
# Amenities: cafe, bar, restaurant, food, store, point_of_interest, establishment
# Open: open_now
#
# Lê Phin
# Amenities: cafe, food, store, point_of_interest, establishment
# Open: open_now
#
# dhom
# Amenities: cafe, bar, restaurant, food, point_of_interest, establishment
# Open: open_now
#
# Luz Cafe
# Amenities: cafe, food, point_of_interest, establishment
# Open: open_now
#
# Boris & Horton
# Amenities: cafe, food, point_of_interest, establishment
# Open: open_now

# %%
# collect 20 cafes from the 10 locations we have set in Manhattan
# Greenwich 20 cafes
import googlemaps
from datetime import datetime

# Set up the Google Maps API client
gmaps = googlemaps.Client(key='AIzaSyAa81xKqSxG-Rh83POFL8Y-TcdXaLGi27k')

location = "40.7336, -74.0027"

# Set up the search parameters
greenwich_params = {
    'location': location,
    'radius': 300,
    'type': 'cafe'
}

# Use the Places API to search for cafes near the location
greenwich_results = gmaps.places_nearby(**greenwich_params)

#Print the name, address, and amenities of each cafe
for place in greenwich_results['results']:
    print(place['name'])
    if 'types' in place:
        print('Amenities:', ', '.join(place['types']))
    if 'opening_hours' in place:
        print('Open:', ', '.join(place['opening_hours']))
    print()
# Out:
# Buvette Gastrotheque
# Amenities: cafe, bar, restaurant, food, point_of_interest, establishment
# Open: open_now
#
# Joe Coffee Company
# Amenities: cafe, store, food, point_of_interest, establishment
# Open: open_now
#
# McNulty's Tea & Coffee Co
# Amenities: cafe, store, food, point_of_interest, establishment
# Open: open_now
#
# Jack’s Stir Brew Coffee
# Amenities: cafe, bakery, store, restaurant, food, point_of_interest, establishment
# Open: open_now
#
# Marie's Crisis Café
# Amenities: cafe, bar, food, point_of_interest, establishment
# Open: open_now
#
# Bantam Bagels
# Amenities: cafe, bakery, meal_takeaway, store, restaurant, food, point_of_interest, establishment
# Open: open_now
#
# Starbucks
# Amenities: cafe, store, restaurant, food, point_of_interest, establishment
# Open: open_now
#
# Milk Bar
# Amenities: cafe, bakery, store, food, point_of_interest, establishment
# Open: open_now
#
# Té Company
# Amenities: cafe, bakery, store, food, point_of_interest, establishment
# Open: open_now
#
# Partners Coffee
# Amenities: cafe, store, food, point_of_interest, establishment
# Open: open_now
#
# ad hoc : coffee + shoppe
# Amenities: cafe, store, food, point_of_interest, establishment
# Open: open_now
#
# Poke Rice
# Amenities: cafe, restaurant, food, point_of_interest, establishment
# Open: open_now
#
# Mah-Ze-Dahr
# Amenities: bakery, cafe, store, restaurant, food, point_of_interest, establishment
# Open: open_now
#
# Dunkin'
# Amenities: cafe, bakery, meal_takeaway, store, restaurant, food, point_of_interest, establishment
# Open: open_now
#
# St Jardim
# Amenities: cafe, bar, store, restaurant, food, point_of_interest, establishment
# Open: open_now
#
# 787 Coffee
# Amenities: cafe, store, food, point_of_interest, establishment
# Open: open_now
#
# Hungry Ghost Coffee
# Amenities: cafe, food, point_of_interest, establishment
# Open: open_now
#
# Do Not Feed Alligators
# Amenities: cafe, bar, book_store, store, food, point_of_interest, establishment
# Open: open_now
#
# Julietta Gelato Cafè
# Amenities: cafe, store, food, point_of_interest, establishment
# Open: open_now
#
# Joji Rooftop
# Amenities: cafe, food, point_of_interest, establishment

# %%
# collect 20 cafes from the 10 locations we have set in Manhattan
# Financial District 20 cafes
import googlemaps
from datetime import datetime

# Set up the Google Maps API client
gmaps = googlemaps.Client(key='AIzaSyAa81xKqSxG-Rh83POFL8Y-TcdXaLGi27k')

location = "40.7075, -74.0113"

# Set up the search parameters
fidi_params = {
    'location': location,
    'radius': 300,
    'type': 'cafe'
}

# Use the Places API to search for cafes near the location
fidi_results = gmaps.places_nearby(**fidi_params)

#Print the name, address, and amenities of each cafe
for place in fidi_results['results']:
    print(place['name'])
    if 'types' in place:
        print('Amenities:', ', '.join(place['types']))
    if 'opening_hours' in place:
        print('Open:', ', '.join(place['opening_hours']))
    print()
# Out:
# McDonald's
# Amenities: cafe, restaurant, food, point_of_interest, store, establishment
# Open: open_now
#
# Pret A Manger
# Amenities: cafe, meal_takeaway, restaurant, food, point_of_interest, store, establishment
# Open: open_now
#
# Dunkin'
# Amenities: bakery, cafe, meal_takeaway, restaurant, food, point_of_interest, store, establishment
# Open: open_now
#
# Bean & Bean Wall St
# Amenities: cafe, meal_takeaway, restaurant, food, point_of_interest, store, establishment
# Open: open_now
#
# Dunkin'
# Amenities: bakery, cafe, meal_takeaway, restaurant, food, point_of_interest, store, establishment
# Open: open_now
#
# Starbucks
# Amenities: cafe, restaurant, food, point_of_interest, store, establishment
# Open: open_now
#
# Schimenti construction
# Amenities: cafe, food, point_of_interest, establishment
# Open: open_now
#
# JOE & THE JUICE
# Amenities: cafe, meal_takeaway, restaurant, food, point_of_interest, store, establishment
# Open: open_now
#
# Gregorys Coffee
# Amenities: cafe, food, point_of_interest, store, establishment
# Open: open_now
#
# Dunkin'
# Amenities: bakery, cafe, meal_takeaway, restaurant, food, point_of_interest, store, establishment
# Open: open_now
#
# Open Market
# Amenities: cafe, grocery_or_supermarket, convenience_store, health, restaurant, food, point_of_interest, store, establishment
# Open: open_now
#
# Dunkin'
# Amenities: bakery, cafe, meal_takeaway, restaurant, food, point_of_interest, store, establishment
# Open: open_now
#
# Dunkin'
# Amenities: bakery, cafe, meal_takeaway, restaurant, food, point_of_interest, store, establishment
# Open: open_now
#
# Javanese Coffee
# Amenities: cafe, food, point_of_interest, establishment
#
# Metropolitan Coffee Company
# Amenities: cafe, food, point_of_interest, store, establishment
# Open: open_now
#
# La Parisienne
# Amenities: restaurant, cafe, grocery_or_supermarket, bar, food, point_of_interest, store, establishment
# Open: open_now
#
# Starbucks
# Amenities: cafe, restaurant, food, point_of_interest, store, establishment
# Open: open_now
#
# Pret A Manger
# Amenities: cafe, meal_takeaway, restaurant, food, point_of_interest, store, establishment
# Open: open_now
#
# Koyzina Kafe
# Amenities: cafe, meal_takeaway, restaurant, food, point_of_interest, establishment
#
# Taz Cafe
# Amenities: cafe, restaurant, food, point_of_interest, establishment
# Open: open_now

# %%
import pandas as pd

# Create an empty dataframe to store the results from the previous data we have collected
df = pd.DataFrame(columns=['Name', 'Address', 'Latitude', 'Longitude', 'Types', 
                           'Price_level', 'Rating', 'Reviews', 'Neighborhood'])

all_results = [uws_results, midtown_results, hellskitchen_results, ues_results, 
               chelsea_results, soho_results, ct_results, ev_results, greenwich_results, fidi_results]

all_results_dict = {"UpperWestSide": uws_results, "Midtown": midtown_results, 
                    "HellsKitchen": hellskitchen_results, "UpperEastSide": ues_results, 
                    "Chelsea": chelsea_results, "Soho": soho_results, "Chinatown": ct_results, 
                    "EastVillage": ev_results, "Greenwich": greenwich_results, 
                    "FinancialDistrict": fidi_results}

for neighborhood, results in all_results_dict.items():
    for result in results['results']:
        # Extract the information for each cafe
        name = result['name']
        address = result.get('vicinity', '')
        latitude = result['geometry']['location']['lat']
        longitude = result['geometry']['location']['lng']
        types = result['types']
        price_level = result.get('price_level', '')
        rating = result.get('rating', '')
        reviews = result.get('user_ratings_total', '')
    
        # Add the information to the dataframe
        df = df.append({'Name': name, 'Address': address, 'Latitude': latitude, 
                        'Longitude': longitude, 'Types': types, 'Price_level': price_level, 
                        'Rating': rating, 'Reviews': reviews, 'Neighborhood': neighborhood}, 
                       ignore_index=True)
        df = df.reset_index(drop=True)  # Reset the index after each row is appended

# Print the dataframe
df
# Out:
# /var/folders/xm/rzbs28zj73574d8v88dn89m80000gn/T/ipykernel_20169/3020659858.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Name': name, 'Address': address, 'Latitude': latitude, 'Longitude': longitude, 'Types': types, 'Price_level': price_level, 'Rating': rating, 'Reviews': reviews, 'Neighborhood': neighborhood}, ignore_index=True)
# /var/folders/xm/rzbs28zj73574d8v88dn89m80000gn/T/ipykernel_20169/3020659858.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Name': name, 'Address': address, 'Latitude': latitude, 'Longitude': longitude, 'Types': types, 'Price_level': price_level, 'Rating': rating, 'Reviews': reviews, 'Neighborhood': neighborhood}, ignore_index=True)
# /var/folders/xm/rzbs28zj73574d8v88dn89m80000gn/T/ipykernel_20169/3020659858.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Name': name, 'Address': address, 'Latitude': latitude, 'Longitude': longitude, 'Types': types, 'Price_level': price_level, 'Rating': rating, 'Reviews': reviews, 'Neighborhood': neighborhood}, ignore_index=True)
# /var/folders/xm/rzbs28zj73574d8v88dn89m80000gn/T/ipykernel_20169/3020659858.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Name': name, 'Address': address, 'Latitude': latitude, 'Longitude': longitude, 'Types': types, 'Price_level': price_level, 'Rating': rating, 'Reviews': reviews, 'Neighborhood': neighborhood}, ignore_index=True)
# /var/folders/xm/rzbs28zj73574d8v88dn89m80000gn/T/ipykernel_20169/3020659858.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Name': name, 'Address': address, 'Latitude': latitude, 'Longitude': longitude, 'Types': types, 'Price_level': price_level, 'Rating': rating, 'Reviews': reviews, 'Neighborhood': neighborhood}, ignore_index=True)
# /var/folders/xm/rzbs28zj73574d8v88dn89m80000gn/T/ipykernel_20169/3020659858.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Name': name, 'Address': address, 'Latitude': latitude, 'Longitude': longitude, 'Types': types, 'Price_level': price_level, 'Rating': rating, 'Reviews': reviews, 'Neighborhood': neighborhood}, ignore_index=True)
# /var/folders/xm/rzbs28zj73574d8v88dn89m80000gn/T/ipykernel_20169/3020659858.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Name': name, 'Address': address, 'Latitude': latitude, 'Longitude': longitude, 'Types': types, 'Price_level': price_level, 'Rating': rating, 'Reviews': reviews, 'Neighborhood': neighborhood}, ignore_index=True)
# /var/folders/xm/rzbs28zj73574d8v88dn89m80000gn/T/ipykernel_20169/3020659858.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Name': name, 'Address': address, 'Latitude': latitude, 'Longitude': longitude, 'Types': types, 'Price_level': price_level, 'Rating': rating, 'Reviews': reviews, 'Neighborhood': neighborhood}, ignore_index=True)
# /var/folders/xm/rzbs28zj73574d8v88dn89m80000gn/T/ipykernel_20169/3020659858.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Name': name, 'Address': address, 'Latitude': latitude, 'Longitude': longitude, 'Types': types, 'Price_level': price_level, 'Rating': rating, 'Reviews': reviews, 'Neighborhood': neighborhood}, ignore_index=True)
# /var/folders/xm/rzbs28zj73574d8v88dn89m80000gn/T/ipykernel_20169/3020659858.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Name': name, 'Address': address, 'Latitude': latitude, 'Longitude': longitude, 'Types': types, 'Price_level': price_level, 'Rating': rating, 'Reviews': reviews, 'Neighborhood': neighborhood}, ignore_index=True)
# /var/folders/xm/rzbs28zj73574d8v88dn89m80000gn/T/ipykernel_20169/3020659858.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Name': name, 'Address': address, 'Latitude': latitude, 'Longitude': longitude, 'Types': types, 'Price_level': price_level, 'Rating': rating, 'Reviews': reviews, 'Neighborhood': neighborhood}, ignore_index=True)
# /var/folders/xm/rzbs28zj73574d8v88dn89m80000gn/T/ipykernel_20169/3020659858.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Name': name, 'Address': address, 'Latitude': latitude, 'Longitude': longitude, 'Types': types, 'Price_level': price_level, 'Rating': rating, 'Reviews': reviews, 'Neighborhood': neighborhood}, ignore_index=True)
# /var/folders/xm/rzbs28zj73574d8v88dn89m80000gn/T/ipykernel_20169/3020659858.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Name': name, 'Address': address, 'Latitude': latitude, 'Longitude': longitude, 'Types': types, 'Price_level': price_level, 'Rating': rating, 'Reviews': reviews, 'Neighborhood': neighborhood}, ignore_index=True)
# /var/folders/xm/rzbs28zj73574d8v88dn89m80000gn/T/ipykernel_20169/3020659858.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Name': name, 'Address': address, 'Latitude': latitude, 'Longitude': longitude, 'Types': types, 'Price_level': price_level, 'Rating': rating, 'Reviews': reviews, 'Neighborhood': neighborhood}, ignore_index=True)
# /var/folders/xm/rzbs28zj73574d8v88dn89m80000gn/T/ipykernel_20169/3020659858.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Name': name, 'Address': address, 'Latitude': latitude, 'Longitude': longitude, 'Types': types, 'Price_level': price_level, 'Rating': rating, 'Reviews': reviews, 'Neighborhood': neighborhood}, ignore_index=True)
# /var/folders/xm/rzbs28zj73574d8v88dn89m80000gn/T/ipykernel_20169/3020659858.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Name': name, 'Address': address, 'Latitude': latitude, 'Longitude': longitude, 'Types': types, 'Price_level': price_level, 'Rating': rating, 'Reviews': reviews, 'Neighborhood': neighborhood}, ignore_index=True)
# /var/folders/xm/rzbs28zj73574d8v88dn89m80000gn/T/ipykernel_20169/3020659858.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Name': name, 'Address': address, 'Latitude': latitude, 'Longitude': longitude, 'Types': types, 'Price_level': price_level, 'Rating': rating, 'Reviews': reviews, 'Neighborhood': neighborhood}, ignore_index=True)
# /var/folders/xm/rzbs28zj73574d8v88dn89m80000gn/T/ipykernel_20169/3020659858.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Name': name, 'Address': address, 'Latitude': latitude, 'Longitude': longitude, 'Types': types, 'Price_level': price_level, 'Rating': rating, 'Reviews': reviews, 'Neighborhood': neighborhood}, ignore_index=True)
# /var/folders/xm/rzbs28zj73574d8v88dn89m80000gn/T/ipykernel_20169/3020659858.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Name': name, 'Address': address, 'Latitude': latitude, 'Longitude': longitude, 'Types': types, 'Price_level': price_level, 'Rating': rating, 'Reviews': reviews, 'Neighborhood': neighborhood}, ignore_index=True)
# /var/folders/xm/rzbs28zj73574d8v88dn89m80000gn/T/ipykernel_20169/3020659858.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Name': name, 'Address': address, 'Latitude': latitude, 'Longitude': longitude, 'Types': types, 'Price_level': price_level, 'Rating': rating, 'Reviews': reviews, 'Neighborhood': neighborhood}, ignore_index=True)
# /var/folders/xm/rzbs28zj73574d8v88dn89m80000gn/T/ipykernel_20169/3020659858.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Name': name, 'Address': address, 'Latitude': latitude, 'Longitude': longitude, 'Types': types, 'Price_level': price_level, 'Rating': rating, 'Reviews': reviews, 'Neighborhood': neighborhood}, ignore_index=True)
# /var/folders/xm/rzbs28zj73574d8v88dn89m80000gn/T/ipykernel_20169/3020659858.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Name': name, 'Address': address, 'Latitude': latitude, 'Longitude': longitude, 'Types': types, 'Price_level': price_level, 'Rating': rating, 'Reviews': reviews, 'Neighborhood': neighborhood}, ignore_index=True)
# /var/folders/xm/rzbs28zj73574d8v88dn89m80000gn/T/ipykernel_20169/3020659858.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Name': name, 'Address': address, 'Latitude': latitude, 'Longitude': longitude, 'Types': types, 'Price_level': price_level, 'Rating': rating, 'Reviews': reviews, 'Neighborhood': neighborhood}, ignore_index=True)
# /var/folders/xm/rzbs28zj73574d8v88dn89m80000gn/T/ipykernel_20169/3020659858.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Name': name, 'Address': address, 'Latitude': latitude, 'Longitude': longitude, 'Types': types, 'Price_level': price_level, 'Rating': rating, 'Reviews': reviews, 'Neighborhood': neighborhood}, ignore_index=True)
# /var/folders/xm/rzbs28zj73574d8v88dn89m80000gn/T/ipykernel_20169/3020659858.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Name': name, 'Address': address, 'Latitude': latitude, 'Longitude': longitude, 'Types': types, 'Price_level': price_level, 'Rating': rating, 'Reviews': reviews, 'Neighborhood': neighborhood}, ignore_index=True)
# /var/folders/xm/rzbs28zj73574d8v88dn89m80000gn/T/ipykernel_20169/3020659858.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Name': name, 'Address': address, 'Latitude': latitude, 'Longitude': longitude, 'Types': types, 'Price_level': price_level, 'Rating': rating, 'Reviews': reviews, 'Neighborhood': neighborhood}, ignore_index=True)
# /var/folders/xm/rzbs28zj73574d8v88dn89m80000gn/T/ipykernel_20169/3020659858.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Name': name, 'Address': address, 'Latitude': latitude, 'Longitude': longitude, 'Types': types, 'Price_level': price_level, 'Rating': rating, 'Reviews': reviews, 'Neighborhood': neighborhood}, ignore_index=True)
# /var/folders/xm/rzbs28zj73574d8v88dn89m80000gn/T/ipykernel_20169/3020659858.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Name': name, 'Address': address, 'Latitude': latitude, 'Longitude': longitude, 'Types': types, 'Price_level': price_level, 'Rating': rating, 'Reviews': reviews, 'Neighborhood': neighborhood}, ignore_index=True)
# /var/folders/xm/rzbs28zj73574d8v88dn89m80000gn/T/ipykernel_20169/3020659858.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Name': name, 'Address': address, 'Latitude': latitude, 'Longitude': longitude, 'Types': types, 'Price_level': price_level, 'Rating': rating, 'Reviews': reviews, 'Neighborhood': neighborhood}, ignore_index=True)
# /var/folders/xm/rzbs28zj73574d8v88dn89m80000gn/T/ipykernel_20169/3020659858.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Name': name, 'Address': address, 'Latitude': latitude, 'Longitude': longitude, 'Types': types, 'Price_level': price_level, 'Rating': rating, 'Reviews': reviews, 'Neighborhood': neighborhood}, ignore_index=True)
# /var/folders/xm/rzbs28zj73574d8v88dn89m80000gn/T/ipykernel_20169/3020659858.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Name': name, 'Address': address, 'Latitude': latitude, 'Longitude': longitude, 'Types': types, 'Price_level': price_level, 'Rating': rating, 'Reviews': reviews, 'Neighborhood': neighborhood}, ignore_index=True)
# /var/folders/xm/rzbs28zj73574d8v88dn89m80000gn/T/ipykernel_20169/3020659858.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Name': name, 'Address': address, 'Latitude': latitude, 'Longitude': longitude, 'Types': types, 'Price_level': price_level, 'Rating': rating, 'Reviews': reviews, 'Neighborhood': neighborhood}, ignore_index=True)
# /var/folders/xm/rzbs28zj73574d8v88dn89m80000gn/T/ipykernel_20169/3020659858.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Name': name, 'Address': address, 'Latitude': latitude, 'Longitude': longitude, 'Types': types, 'Price_level': price_level, 'Rating': rating, 'Reviews': reviews, 'Neighborhood': neighborhood}, ignore_index=True)
# /var/folders/xm/rzbs28zj73574d8v88dn89m80000gn/T/ipykernel_20169/3020659858.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Name': name, 'Address': address, 'Latitude': latitude, 'Longitude': longitude, 'Types': types, 'Price_level': price_level, 'Rating': rating, 'Reviews': reviews, 'Neighborhood': neighborhood}, ignore_index=True)
# /var/folders/xm/rzbs28zj73574d8v88dn89m80000gn/T/ipykernel_20169/3020659858.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Name': name, 'Address': address, 'Latitude': latitude, 'Longitude': longitude, 'Types': types, 'Price_level': price_level, 'Rating': rating, 'Reviews': reviews, 'Neighborhood': neighborhood}, ignore_index=True)
# /var/folders/xm/rzbs28zj73574d8v88dn89m80000gn/T/ipykernel_20169/3020659858.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Name': name, 'Address': address, 'Latitude': latitude, 'Longitude': longitude, 'Types': types, 'Price_level': price_level, 'Rating': rating, 'Reviews': reviews, 'Neighborhood': neighborhood}, ignore_index=True)
# /var/folders/xm/rzbs28zj73574d8v88dn89m80000gn/T/ipykernel_20169/3020659858.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Name': name, 'Address': address, 'Latitude': latitude, 'Longitude': longitude, 'Types': types, 'Price_level': price_level, 'Rating': rating, 'Reviews': reviews, 'Neighborhood': neighborhood}, ignore_index=True)
# /var/folders/xm/rzbs28zj73574d8v88dn89m80000gn/T/ipykernel_20169/3020659858.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Name': name, 'Address': address, 'Latitude': latitude, 'Longitude': longitude, 'Types': types, 'Price_level': price_level, 'Rating': rating, 'Reviews': reviews, 'Neighborhood': neighborhood}, ignore_index=True)
# /var/folders/xm/rzbs28zj73574d8v88dn89m80000gn/T/ipykernel_20169/3020659858.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Name': name, 'Address': address, 'Latitude': latitude, 'Longitude': longitude, 'Types': types, 'Price_level': price_level, 'Rating': rating, 'Reviews': reviews, 'Neighborhood': neighborhood}, ignore_index=True)
# /var/folders/xm/rzbs28zj73574d8v88dn89m80000gn/T/ipykernel_20169/3020659858.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Name': name, 'Address': address, 'Latitude': latitude, 'Longitude': longitude, 'Types': types, 'Price_level': price_level, 'Rating': rating, 'Reviews': reviews, 'Neighborhood': neighborhood}, ignore_index=True)
# /var/folders/xm/rzbs28zj73574d8v88dn89m80000gn/T/ipykernel_20169/3020659858.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Name': name, 'Address': address, 'Latitude': latitude, 'Longitude': longitude, 'Types': types, 'Price_level': price_level, 'Rating': rating, 'Reviews': reviews, 'Neighborhood': neighborhood}, ignore_index=True)
# /var/folders/xm/rzbs28zj73574d8v88dn89m80000gn/T/ipykernel_20169/3020659858.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Name': name, 'Address': address, 'Latitude': latitude, 'Longitude': longitude, 'Types': types, 'Price_level': price_level, 'Rating': rating, 'Reviews': reviews, 'Neighborhood': neighborhood}, ignore_index=True)
# /var/folders/xm/rzbs28zj73574d8v88dn89m80000gn/T/ipykernel_20169/3020659858.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Name': name, 'Address': address, 'Latitude': latitude, 'Longitude': longitude, 'Types': types, 'Price_level': price_level, 'Rating': rating, 'Reviews': reviews, 'Neighborhood': neighborhood}, ignore_index=True)
# /var/folders/xm/rzbs28zj73574d8v88dn89m80000gn/T/ipykernel_20169/3020659858.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Name': name, 'Address': address, 'Latitude': latitude, 'Longitude': longitude, 'Types': types, 'Price_level': price_level, 'Rating': rating, 'Reviews': reviews, 'Neighborhood': neighborhood}, ignore_index=True)
# /var/folders/xm/rzbs28zj73574d8v88dn89m80000gn/T/ipykernel_20169/3020659858.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Name': name, 'Address': address, 'Latitude': latitude, 'Longitude': longitude, 'Types': types, 'Price_level': price_level, 'Rating': rating, 'Reviews': reviews, 'Neighborhood': neighborhood}, ignore_index=True)
# /var/folders/xm/rzbs28zj73574d8v88dn89m80000gn/T/ipykernel_20169/3020659858.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Name': name, 'Address': address, 'Latitude': latitude, 'Longitude': longitude, 'Types': types, 'Price_level': price_level, 'Rating': rating, 'Reviews': reviews, 'Neighborhood': neighborhood}, ignore_index=True)
# /var/folders/xm/rzbs28zj73574d8v88dn89m80000gn/T/ipykernel_20169/3020659858.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Name': name, 'Address': address, 'Latitude': latitude, 'Longitude': longitude, 'Types': types, 'Price_level': price_level, 'Rating': rating, 'Reviews': reviews, 'Neighborhood': neighborhood}, ignore_index=True)
# /var/folders/xm/rzbs28zj73574d8v88dn89m80000gn/T/ipykernel_20169/3020659858.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Name': name, 'Address': address, 'Latitude': latitude, 'Longitude': longitude, 'Types': types, 'Price_level': price_level, 'Rating': rating, 'Reviews': reviews, 'Neighborhood': neighborhood}, ignore_index=True)
# /var/folders/xm/rzbs28zj73574d8v88dn89m80000gn/T/ipykernel_20169/3020659858.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Name': name, 'Address': address, 'Latitude': latitude, 'Longitude': longitude, 'Types': types, 'Price_level': price_level, 'Rating': rating, 'Reviews': reviews, 'Neighborhood': neighborhood}, ignore_index=True)
# /var/folders/xm/rzbs28zj73574d8v88dn89m80000gn/T/ipykernel_20169/3020659858.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Name': name, 'Address': address, 'Latitude': latitude, 'Longitude': longitude, 'Types': types, 'Price_level': price_level, 'Rating': rating, 'Reviews': reviews, 'Neighborhood': neighborhood}, ignore_index=True)
# /var/folders/xm/rzbs28zj73574d8v88dn89m80000gn/T/ipykernel_20169/3020659858.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Name': name, 'Address': address, 'Latitude': latitude, 'Longitude': longitude, 'Types': types, 'Price_level': price_level, 'Rating': rating, 'Reviews': reviews, 'Neighborhood': neighborhood}, ignore_index=True)
# /var/folders/xm/rzbs28zj73574d8v88dn89m80000gn/T/ipykernel_20169/3020659858.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Name': name, 'Address': address, 'Latitude': latitude, 'Longitude': longitude, 'Types': types, 'Price_level': price_level, 'Rating': rating, 'Reviews': reviews, 'Neighborhood': neighborhood}, ignore_index=True)
# /var/folders/xm/rzbs28zj73574d8v88dn89m80000gn/T/ipykernel_20169/3020659858.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Name': name, 'Address': address, 'Latitude': latitude, 'Longitude': longitude, 'Types': types, 'Price_level': price_level, 'Rating': rating, 'Reviews': reviews, 'Neighborhood': neighborhood}, ignore_index=True)
# /var/folders/xm/rzbs28zj73574d8v88dn89m80000gn/T/ipykernel_20169/3020659858.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Name': name, 'Address': address, 'Latitude': latitude, 'Longitude': longitude, 'Types': types, 'Price_level': price_level, 'Rating': rating, 'Reviews': reviews, 'Neighborhood': neighborhood}, ignore_index=True)
# /var/folders/xm/rzbs28zj73574d8v88dn89m80000gn/T/ipykernel_20169/3020659858.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Name': name, 'Address': address, 'Latitude': latitude, 'Longitude': longitude, 'Types': types, 'Price_level': price_level, 'Rating': rating, 'Reviews': reviews, 'Neighborhood': neighborhood}, ignore_index=True)
# /var/folders/xm/rzbs28zj73574d8v88dn89m80000gn/T/ipykernel_20169/3020659858.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Name': name, 'Address': address, 'Latitude': latitude, 'Longitude': longitude, 'Types': types, 'Price_level': price_level, 'Rating': rating, 'Reviews': reviews, 'Neighborhood': neighborhood}, ignore_index=True)
# /var/folders/xm/rzbs28zj73574d8v88dn89m80000gn/T/ipykernel_20169/3020659858.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Name': name, 'Address': address, 'Latitude': latitude, 'Longitude': longitude, 'Types': types, 'Price_level': price_level, 'Rating': rating, 'Reviews': reviews, 'Neighborhood': neighborhood}, ignore_index=True)
# /var/folders/xm/rzbs28zj73574d8v88dn89m80000gn/T/ipykernel_20169/3020659858.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Name': name, 'Address': address, 'Latitude': latitude, 'Longitude': longitude, 'Types': types, 'Price_level': price_level, 'Rating': rating, 'Reviews': reviews, 'Neighborhood': neighborhood}, ignore_index=True)
# /var/folders/xm/rzbs28zj73574d8v88dn89m80000gn/T/ipykernel_20169/3020659858.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Name': name, 'Address': address, 'Latitude': latitude, 'Longitude': longitude, 'Types': types, 'Price_level': price_level, 'Rating': rating, 'Reviews': reviews, 'Neighborhood': neighborhood}, ignore_index=True)
# /var/folders/xm/rzbs28zj73574d8v88dn89m80000gn/T/ipykernel_20169/3020659858.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Name': name, 'Address': address, 'Latitude': latitude, 'Longitude': longitude, 'Types': types, 'Price_level': price_level, 'Rating': rating, 'Reviews': reviews, 'Neighborhood': neighborhood}, ignore_index=True)
# /var/folders/xm/rzbs28zj73574d8v88dn89m80000gn/T/ipykernel_20169/3020659858.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Name': name, 'Address': address, 'Latitude': latitude, 'Longitude': longitude, 'Types': types, 'Price_level': price_level, 'Rating': rating, 'Reviews': reviews, 'Neighborhood': neighborhood}, ignore_index=True)
# /var/folders/xm/rzbs28zj73574d8v88dn89m80000gn/T/ipykernel_20169/3020659858.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Name': name, 'Address': address, 'Latitude': latitude, 'Longitude': longitude, 'Types': types, 'Price_level': price_level, 'Rating': rating, 'Reviews': reviews, 'Neighborhood': neighborhood}, ignore_index=True)
# /var/folders/xm/rzbs28zj73574d8v88dn89m80000gn/T/ipykernel_20169/3020659858.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Name': name, 'Address': address, 'Latitude': latitude, 'Longitude': longitude, 'Types': types, 'Price_level': price_level, 'Rating': rating, 'Reviews': reviews, 'Neighborhood': neighborhood}, ignore_index=True)
# /var/folders/xm/rzbs28zj73574d8v88dn89m80000gn/T/ipykernel_20169/3020659858.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Name': name, 'Address': address, 'Latitude': latitude, 'Longitude': longitude, 'Types': types, 'Price_level': price_level, 'Rating': rating, 'Reviews': reviews, 'Neighborhood': neighborhood}, ignore_index=True)
# /var/folders/xm/rzbs28zj73574d8v88dn89m80000gn/T/ipykernel_20169/3020659858.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Name': name, 'Address': address, 'Latitude': latitude, 'Longitude': longitude, 'Types': types, 'Price_level': price_level, 'Rating': rating, 'Reviews': reviews, 'Neighborhood': neighborhood}, ignore_index=True)
# /var/folders/xm/rzbs28zj73574d8v88dn89m80000gn/T/ipykernel_20169/3020659858.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Name': name, 'Address': address, 'Latitude': latitude, 'Longitude': longitude, 'Types': types, 'Price_level': price_level, 'Rating': rating, 'Reviews': reviews, 'Neighborhood': neighborhood}, ignore_index=True)
# /var/folders/xm/rzbs28zj73574d8v88dn89m80000gn/T/ipykernel_20169/3020659858.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Name': name, 'Address': address, 'Latitude': latitude, 'Longitude': longitude, 'Types': types, 'Price_level': price_level, 'Rating': rating, 'Reviews': reviews, 'Neighborhood': neighborhood}, ignore_index=True)
# /var/folders/xm/rzbs28zj73574d8v88dn89m80000gn/T/ipykernel_20169/3020659858.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Name': name, 'Address': address, 'Latitude': latitude, 'Longitude': longitude, 'Types': types, 'Price_level': price_level, 'Rating': rating, 'Reviews': reviews, 'Neighborhood': neighborhood}, ignore_index=True)
# /var/folders/xm/rzbs28zj73574d8v88dn89m80000gn/T/ipykernel_20169/3020659858.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Name': name, 'Address': address, 'Latitude': latitude, 'Longitude': longitude, 'Types': types, 'Price_level': price_level, 'Rating': rating, 'Reviews': reviews, 'Neighborhood': neighborhood}, ignore_index=True)
# /var/folders/xm/rzbs28zj73574d8v88dn89m80000gn/T/ipykernel_20169/3020659858.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Name': name, 'Address': address, 'Latitude': latitude, 'Longitude': longitude, 'Types': types, 'Price_level': price_level, 'Rating': rating, 'Reviews': reviews, 'Neighborhood': neighborhood}, ignore_index=True)
# /var/folders/xm/rzbs28zj73574d8v88dn89m80000gn/T/ipykernel_20169/3020659858.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Name': name, 'Address': address, 'Latitude': latitude, 'Longitude': longitude, 'Types': types, 'Price_level': price_level, 'Rating': rating, 'Reviews': reviews, 'Neighborhood': neighborhood}, ignore_index=True)
# /var/folders/xm/rzbs28zj73574d8v88dn89m80000gn/T/ipykernel_20169/3020659858.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Name': name, 'Address': address, 'Latitude': latitude, 'Longitude': longitude, 'Types': types, 'Price_level': price_level, 'Rating': rating, 'Reviews': reviews, 'Neighborhood': neighborhood}, ignore_index=True)
# /var/folders/xm/rzbs28zj73574d8v88dn89m80000gn/T/ipykernel_20169/3020659858.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Name': name, 'Address': address, 'Latitude': latitude, 'Longitude': longitude, 'Types': types, 'Price_level': price_level, 'Rating': rating, 'Reviews': reviews, 'Neighborhood': neighborhood}, ignore_index=True)
# /var/folders/xm/rzbs28zj73574d8v88dn89m80000gn/T/ipykernel_20169/3020659858.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Name': name, 'Address': address, 'Latitude': latitude, 'Longitude': longitude, 'Types': types, 'Price_level': price_level, 'Rating': rating, 'Reviews': reviews, 'Neighborhood': neighborhood}, ignore_index=True)
# /var/folders/xm/rzbs28zj73574d8v88dn89m80000gn/T/ipykernel_20169/3020659858.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Name': name, 'Address': address, 'Latitude': latitude, 'Longitude': longitude, 'Types': types, 'Price_level': price_level, 'Rating': rating, 'Reviews': reviews, 'Neighborhood': neighborhood}, ignore_index=True)
# /var/folders/xm/rzbs28zj73574d8v88dn89m80000gn/T/ipykernel_20169/3020659858.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Name': name, 'Address': address, 'Latitude': latitude, 'Longitude': longitude, 'Types': types, 'Price_level': price_level, 'Rating': rating, 'Reviews': reviews, 'Neighborhood': neighborhood}, ignore_index=True)
# /var/folders/xm/rzbs28zj73574d8v88dn89m80000gn/T/ipykernel_20169/3020659858.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Name': name, 'Address': address, 'Latitude': latitude, 'Longitude': longitude, 'Types': types, 'Price_level': price_level, 'Rating': rating, 'Reviews': reviews, 'Neighborhood': neighborhood}, ignore_index=True)
# /var/folders/xm/rzbs28zj73574d8v88dn89m80000gn/T/ipykernel_20169/3020659858.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Name': name, 'Address': address, 'Latitude': latitude, 'Longitude': longitude, 'Types': types, 'Price_level': price_level, 'Rating': rating, 'Reviews': reviews, 'Neighborhood': neighborhood}, ignore_index=True)
# /var/folders/xm/rzbs28zj73574d8v88dn89m80000gn/T/ipykernel_20169/3020659858.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Name': name, 'Address': address, 'Latitude': latitude, 'Longitude': longitude, 'Types': types, 'Price_level': price_level, 'Rating': rating, 'Reviews': reviews, 'Neighborhood': neighborhood}, ignore_index=True)
# /var/folders/xm/rzbs28zj73574d8v88dn89m80000gn/T/ipykernel_20169/3020659858.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Name': name, 'Address': address, 'Latitude': latitude, 'Longitude': longitude, 'Types': types, 'Price_level': price_level, 'Rating': rating, 'Reviews': reviews, 'Neighborhood': neighborhood}, ignore_index=True)
# /var/folders/xm/rzbs28zj73574d8v88dn89m80000gn/T/ipykernel_20169/3020659858.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Name': name, 'Address': address, 'Latitude': latitude, 'Longitude': longitude, 'Types': types, 'Price_level': price_level, 'Rating': rating, 'Reviews': reviews, 'Neighborhood': neighborhood}, ignore_index=True)
# /var/folders/xm/rzbs28zj73574d8v88dn89m80000gn/T/ipykernel_20169/3020659858.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Name': name, 'Address': address, 'Latitude': latitude, 'Longitude': longitude, 'Types': types, 'Price_level': price_level, 'Rating': rating, 'Reviews': reviews, 'Neighborhood': neighborhood}, ignore_index=True)
# /var/folders/xm/rzbs28zj73574d8v88dn89m80000gn/T/ipykernel_20169/3020659858.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Name': name, 'Address': address, 'Latitude': latitude, 'Longitude': longitude, 'Types': types, 'Price_level': price_level, 'Rating': rating, 'Reviews': reviews, 'Neighborhood': neighborhood}, ignore_index=True)
# /var/folders/xm/rzbs28zj73574d8v88dn89m80000gn/T/ipykernel_20169/3020659858.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Name': name, 'Address': address, 'Latitude': latitude, 'Longitude': longitude, 'Types': types, 'Price_level': price_level, 'Rating': rating, 'Reviews': reviews, 'Neighborhood': neighborhood}, ignore_index=True)
# /var/folders/xm/rzbs28zj73574d8v88dn89m80000gn/T/ipykernel_20169/3020659858.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Name': name, 'Address': address, 'Latitude': latitude, 'Longitude': longitude, 'Types': types, 'Price_level': price_level, 'Rating': rating, 'Reviews': reviews, 'Neighborhood': neighborhood}, ignore_index=True)
# /var/folders/xm/rzbs28zj73574d8v88dn89m80000gn/T/ipykernel_20169/3020659858.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Name': name, 'Address': address, 'Latitude': latitude, 'Longitude': longitude, 'Types': types, 'Price_level': price_level, 'Rating': rating, 'Reviews': reviews, 'Neighborhood': neighborhood}, ignore_index=True)
# /var/folders/xm/rzbs28zj73574d8v88dn89m80000gn/T/ipykernel_20169/3020659858.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Name': name, 'Address': address, 'Latitude': latitude, 'Longitude': longitude, 'Types': types, 'Price_level': price_level, 'Rating': rating, 'Reviews': reviews, 'Neighborhood': neighborhood}, ignore_index=True)
# /var/folders/xm/rzbs28zj73574d8v88dn89m80000gn/T/ipykernel_20169/3020659858.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Name': name, 'Address': address, 'Latitude': latitude, 'Longitude': longitude, 'Types': types, 'Price_level': price_level, 'Rating': rating, 'Reviews': reviews, 'Neighborhood': neighborhood}, ignore_index=True)
# /var/folders/xm/rzbs28zj73574d8v88dn89m80000gn/T/ipykernel_20169/3020659858.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Name': name, 'Address': address, 'Latitude': latitude, 'Longitude': longitude, 'Types': types, 'Price_level': price_level, 'Rating': rating, 'Reviews': reviews, 'Neighborhood': neighborhood}, ignore_index=True)
# /var/folders/xm/rzbs28zj73574d8v88dn89m80000gn/T/ipykernel_20169/3020659858.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Name': name, 'Address': address, 'Latitude': latitude, 'Longitude': longitude, 'Types': types, 'Price_level': price_level, 'Rating': rating, 'Reviews': reviews, 'Neighborhood': neighborhood}, ignore_index=True)
# /var/folders/xm/rzbs28zj73574d8v88dn89m80000gn/T/ipykernel_20169/3020659858.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Name': name, 'Address': address, 'Latitude': latitude, 'Longitude': longitude, 'Types': types, 'Price_level': price_level, 'Rating': rating, 'Reviews': reviews, 'Neighborhood': neighborhood}, ignore_index=True)
# /var/folders/xm/rzbs28zj73574d8v88dn89m80000gn/T/ipykernel_20169/3020659858.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Name': name, 'Address': address, 'Latitude': latitude, 'Longitude': longitude, 'Types': types, 'Price_level': price_level, 'Rating': rating, 'Reviews': reviews, 'Neighborhood': neighborhood}, ignore_index=True)
# /var/folders/xm/rzbs28zj73574d8v88dn89m80000gn/T/ipykernel_20169/3020659858.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Name': name, 'Address': address, 'Latitude': latitude, 'Longitude': longitude, 'Types': types, 'Price_level': price_level, 'Rating': rating, 'Reviews': reviews, 'Neighborhood': neighborhood}, ignore_index=True)
# /var/folders/xm/rzbs28zj73574d8v88dn89m80000gn/T/ipykernel_20169/3020659858.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Name': name, 'Address': address, 'Latitude': latitude, 'Longitude': longitude, 'Types': types, 'Price_level': price_level, 'Rating': rating, 'Reviews': reviews, 'Neighborhood': neighborhood}, ignore_index=True)
# /var/folders/xm/rzbs28zj73574d8v88dn89m80000gn/T/ipykernel_20169/3020659858.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Name': name, 'Address': address, 'Latitude': latitude, 'Longitude': longitude, 'Types': types, 'Price_level': price_level, 'Rating': rating, 'Reviews': reviews, 'Neighborhood': neighborhood}, ignore_index=True)
# /var/folders/xm/rzbs28zj73574d8v88dn89m80000gn/T/ipykernel_20169/3020659858.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Name': name, 'Address': address, 'Latitude': latitude, 'Longitude': longitude, 'Types': types, 'Price_level': price_level, 'Rating': rating, 'Reviews': reviews, 'Neighborhood': neighborhood}, ignore_index=True)
# /var/folders/xm/rzbs28zj73574d8v88dn89m80000gn/T/ipykernel_20169/3020659858.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Name': name, 'Address': address, 'Latitude': latitude, 'Longitude': longitude, 'Types': types, 'Price_level': price_level, 'Rating': rating, 'Reviews': reviews, 'Neighborhood': neighborhood}, ignore_index=True)
# /var/folders/xm/rzbs28zj73574d8v88dn89m80000gn/T/ipykernel_20169/3020659858.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Name': name, 'Address': address, 'Latitude': latitude, 'Longitude': longitude, 'Types': types, 'Price_level': price_level, 'Rating': rating, 'Reviews': reviews, 'Neighborhood': neighborhood}, ignore_index=True)
# /var/folders/xm/rzbs28zj73574d8v88dn89m80000gn/T/ipykernel_20169/3020659858.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Name': name, 'Address': address, 'Latitude': latitude, 'Longitude': longitude, 'Types': types, 'Price_level': price_level, 'Rating': rating, 'Reviews': reviews, 'Neighborhood': neighborhood}, ignore_index=True)
# /var/folders/xm/rzbs28zj73574d8v88dn89m80000gn/T/ipykernel_20169/3020659858.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Name': name, 'Address': address, 'Latitude': latitude, 'Longitude': longitude, 'Types': types, 'Price_level': price_level, 'Rating': rating, 'Reviews': reviews, 'Neighborhood': neighborhood}, ignore_index=True)
# /var/folders/xm/rzbs28zj73574d8v88dn89m80000gn/T/ipykernel_20169/3020659858.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Name': name, 'Address': address, 'Latitude': latitude, 'Longitude': longitude, 'Types': types, 'Price_level': price_level, 'Rating': rating, 'Reviews': reviews, 'Neighborhood': neighborhood}, ignore_index=True)
# /var/folders/xm/rzbs28zj73574d8v88dn89m80000gn/T/ipykernel_20169/3020659858.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Name': name, 'Address': address, 'Latitude': latitude, 'Longitude': longitude, 'Types': types, 'Price_level': price_level, 'Rating': rating, 'Reviews': reviews, 'Neighborhood': neighborhood}, ignore_index=True)
# /var/folders/xm/rzbs28zj73574d8v88dn89m80000gn/T/ipykernel_20169/3020659858.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Name': name, 'Address': address, 'Latitude': latitude, 'Longitude': longitude, 'Types': types, 'Price_level': price_level, 'Rating': rating, 'Reviews': reviews, 'Neighborhood': neighborhood}, ignore_index=True)
# /var/folders/xm/rzbs28zj73574d8v88dn89m80000gn/T/ipykernel_20169/3020659858.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Name': name, 'Address': address, 'Latitude': latitude, 'Longitude': longitude, 'Types': types, 'Price_level': price_level, 'Rating': rating, 'Reviews': reviews, 'Neighborhood': neighborhood}, ignore_index=True)
# /var/folders/xm/rzbs28zj73574d8v88dn89m80000gn/T/ipykernel_20169/3020659858.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Name': name, 'Address': address, 'Latitude': latitude, 'Longitude': longitude, 'Types': types, 'Price_level': price_level, 'Rating': rating, 'Reviews': reviews, 'Neighborhood': neighborhood}, ignore_index=True)
# /var/folders/xm/rzbs28zj73574d8v88dn89m80000gn/T/ipykernel_20169/3020659858.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Name': name, 'Address': address, 'Latitude': latitude, 'Longitude': longitude, 'Types': types, 'Price_level': price_level, 'Rating': rating, 'Reviews': reviews, 'Neighborhood': neighborhood}, ignore_index=True)
# /var/folders/xm/rzbs28zj73574d8v88dn89m80000gn/T/ipykernel_20169/3020659858.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Name': name, 'Address': address, 'Latitude': latitude, 'Longitude': longitude, 'Types': types, 'Price_level': price_level, 'Rating': rating, 'Reviews': reviews, 'Neighborhood': neighborhood}, ignore_index=True)
# /var/folders/xm/rzbs28zj73574d8v88dn89m80000gn/T/ipykernel_20169/3020659858.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# ...
#   df = df.append({'Name': name, 'Address': address, 'Latitude': latitude, 'Longitude': longitude, 'Types': types, 'Price_level': price_level, 'Rating': rating, 'Reviews': reviews, 'Neighborhood': neighborhood}, ignore_index=True)
# /var/folders/xm/rzbs28zj73574d8v88dn89m80000gn/T/ipykernel_20169/3020659858.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Name': name, 'Address': address, 'Latitude': latitude, 'Longitude': longitude, 'Types': types, 'Price_level': price_level, 'Rating': rating, 'Reviews': reviews, 'Neighborhood': neighborhood}, ignore_index=True)
# /var/folders/xm/rzbs28zj73574d8v88dn89m80000gn/T/ipykernel_20169/3020659858.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Name': name, 'Address': address, 'Latitude': latitude, 'Longitude': longitude, 'Types': types, 'Price_level': price_level, 'Rating': rating, 'Reviews': reviews, 'Neighborhood': neighborhood}, ignore_index=True)
# /var/folders/xm/rzbs28zj73574d8v88dn89m80000gn/T/ipykernel_20169/3020659858.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Name': name, 'Address': address, 'Latitude': latitude, 'Longitude': longitude, 'Types': types, 'Price_level': price_level, 'Rating': rating, 'Reviews': reviews, 'Neighborhood': neighborhood}, ignore_index=True)
# /var/folders/xm/rzbs28zj73574d8v88dn89m80000gn/T/ipykernel_20169/3020659858.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Name': name, 'Address': address, 'Latitude': latitude, 'Longitude': longitude, 'Types': types, 'Price_level': price_level, 'Rating': rating, 'Reviews': reviews, 'Neighborhood': neighborhood}, ignore_index=True)
# /var/folders/xm/rzbs28zj73574d8v88dn89m80000gn/T/ipykernel_20169/3020659858.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Name': name, 'Address': address, 'Latitude': latitude, 'Longitude': longitude, 'Types': types, 'Price_level': price_level, 'Rating': rating, 'Reviews': reviews, 'Neighborhood': neighborhood}, ignore_index=True)
# /var/folders/xm/rzbs28zj73574d8v88dn89m80000gn/T/ipykernel_20169/3020659858.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Name': name, 'Address': address, 'Latitude': latitude, 'Longitude': longitude, 'Types': types, 'Price_level': price_level, 'Rating': rating, 'Reviews': reviews, 'Neighborhood': neighborhood}, ignore_index=True)
# /var/folders/xm/rzbs28zj73574d8v88dn89m80000gn/T/ipykernel_20169/3020659858.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Name': name, 'Address': address, 'Latitude': latitude, 'Longitude': longitude, 'Types': types, 'Price_level': price_level, 'Rating': rating, 'Reviews': reviews, 'Neighborhood': neighborhood}, ignore_index=True)
# /var/folders/xm/rzbs28zj73574d8v88dn89m80000gn/T/ipykernel_20169/3020659858.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Name': name, 'Address': address, 'Latitude': latitude, 'Longitude': longitude, 'Types': types, 'Price_level': price_level, 'Rating': rating, 'Reviews': reviews, 'Neighborhood': neighborhood}, ignore_index=True)
# /var/folders/xm/rzbs28zj73574d8v88dn89m80000gn/T/ipykernel_20169/3020659858.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Name': name, 'Address': address, 'Latitude': latitude, 'Longitude': longitude, 'Types': types, 'Price_level': price_level, 'Rating': rating, 'Reviews': reviews, 'Neighborhood': neighborhood}, ignore_index=True)
# /var/folders/xm/rzbs28zj73574d8v88dn89m80000gn/T/ipykernel_20169/3020659858.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Name': name, 'Address': address, 'Latitude': latitude, 'Longitude': longitude, 'Types': types, 'Price_level': price_level, 'Rating': rating, 'Reviews': reviews, 'Neighborhood': neighborhood}, ignore_index=True)
# /var/folders/xm/rzbs28zj73574d8v88dn89m80000gn/T/ipykernel_20169/3020659858.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Name': name, 'Address': address, 'Latitude': latitude, 'Longitude': longitude, 'Types': types, 'Price_level': price_level, 'Rating': rating, 'Reviews': reviews, 'Neighborhood': neighborhood}, ignore_index=True)
# /var/folders/xm/rzbs28zj73574d8v88dn89m80000gn/T/ipykernel_20169/3020659858.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Name': name, 'Address': address, 'Latitude': latitude, 'Longitude': longitude, 'Types': types, 'Price_level': price_level, 'Rating': rating, 'Reviews': reviews, 'Neighborhood': neighborhood}, ignore_index=True)
# /var/folders/xm/rzbs28zj73574d8v88dn89m80000gn/T/ipykernel_20169/3020659858.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Name': name, 'Address': address, 'Latitude': latitude, 'Longitude': longitude, 'Types': types, 'Price_level': price_level, 'Rating': rating, 'Reviews': reviews, 'Neighborhood': neighborhood}, ignore_index=True)
# /var/folders/xm/rzbs28zj73574d8v88dn89m80000gn/T/ipykernel_20169/3020659858.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Name': name, 'Address': address, 'Latitude': latitude, 'Longitude': longitude, 'Types': types, 'Price_level': price_level, 'Rating': rating, 'Reviews': reviews, 'Neighborhood': neighborhood}, ignore_index=True)
# /var/folders/xm/rzbs28zj73574d8v88dn89m80000gn/T/ipykernel_20169/3020659858.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Name': name, 'Address': address, 'Latitude': latitude, 'Longitude': longitude, 'Types': types, 'Price_level': price_level, 'Rating': rating, 'Reviews': reviews, 'Neighborhood': neighborhood}, ignore_index=True)
# /var/folders/xm/rzbs28zj73574d8v88dn89m80000gn/T/ipykernel_20169/3020659858.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Name': name, 'Address': address, 'Latitude': latitude, 'Longitude': longitude, 'Types': types, 'Price_level': price_level, 'Rating': rating, 'Reviews': reviews, 'Neighborhood': neighborhood}, ignore_index=True)
# /var/folders/xm/rzbs28zj73574d8v88dn89m80000gn/T/ipykernel_20169/3020659858.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Name': name, 'Address': address, 'Latitude': latitude, 'Longitude': longitude, 'Types': types, 'Price_level': price_level, 'Rating': rating, 'Reviews': reviews, 'Neighborhood': neighborhood}, ignore_index=True)
# /var/folders/xm/rzbs28zj73574d8v88dn89m80000gn/T/ipykernel_20169/3020659858.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Name': name, 'Address': address, 'Latitude': latitude, 'Longitude': longitude, 'Types': types, 'Price_level': price_level, 'Rating': rating, 'Reviews': reviews, 'Neighborhood': neighborhood}, ignore_index=True)
# /var/folders/xm/rzbs28zj73574d8v88dn89m80000gn/T/ipykernel_20169/3020659858.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Name': name, 'Address': address, 'Latitude': latitude, 'Longitude': longitude, 'Types': types, 'Price_level': price_level, 'Rating': rating, 'Reviews': reviews, 'Neighborhood': neighborhood}, ignore_index=True)
# /var/folders/xm/rzbs28zj73574d8v88dn89m80000gn/T/ipykernel_20169/3020659858.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Name': name, 'Address': address, 'Latitude': latitude, 'Longitude': longitude, 'Types': types, 'Price_level': price_level, 'Rating': rating, 'Reviews': reviews, 'Neighborhood': neighborhood}, ignore_index=True)
# /var/folders/xm/rzbs28zj73574d8v88dn89m80000gn/T/ipykernel_20169/3020659858.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Name': name, 'Address': address, 'Latitude': latitude, 'Longitude': longitude, 'Types': types, 'Price_level': price_level, 'Rating': rating, 'Reviews': reviews, 'Neighborhood': neighborhood}, ignore_index=True)
# /var/folders/xm/rzbs28zj73574d8v88dn89m80000gn/T/ipykernel_20169/3020659858.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Name': name, 'Address': address, 'Latitude': latitude, 'Longitude': longitude, 'Types': types, 'Price_level': price_level, 'Rating': rating, 'Reviews': reviews, 'Neighborhood': neighborhood}, ignore_index=True)
# /var/folders/xm/rzbs28zj73574d8v88dn89m80000gn/T/ipykernel_20169/3020659858.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Name': name, 'Address': address, 'Latitude': latitude, 'Longitude': longitude, 'Types': types, 'Price_level': price_level, 'Rating': rating, 'Reviews': reviews, 'Neighborhood': neighborhood}, ignore_index=True)
# /var/folders/xm/rzbs28zj73574d8v88dn89m80000gn/T/ipykernel_20169/3020659858.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Name': name, 'Address': address, 'Latitude': latitude, 'Longitude': longitude, 'Types': types, 'Price_level': price_level, 'Rating': rating, 'Reviews': reviews, 'Neighborhood': neighborhood}, ignore_index=True)
# /var/folders/xm/rzbs28zj73574d8v88dn89m80000gn/T/ipykernel_20169/3020659858.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Name': name, 'Address': address, 'Latitude': latitude, 'Longitude': longitude, 'Types': types, 'Price_level': price_level, 'Rating': rating, 'Reviews': reviews, 'Neighborhood': neighborhood}, ignore_index=True)
# /var/folders/xm/rzbs28zj73574d8v88dn89m80000gn/T/ipykernel_20169/3020659858.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Name': name, 'Address': address, 'Latitude': latitude, 'Longitude': longitude, 'Types': types, 'Price_level': price_level, 'Rating': rating, 'Reviews': reviews, 'Neighborhood': neighborhood}, ignore_index=True)
# /var/folders/xm/rzbs28zj73574d8v88dn89m80000gn/T/ipykernel_20169/3020659858.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Name': name, 'Address': address, 'Latitude': latitude, 'Longitude': longitude, 'Types': types, 'Price_level': price_level, 'Rating': rating, 'Reviews': reviews, 'Neighborhood': neighborhood}, ignore_index=True)
# /var/folders/xm/rzbs28zj73574d8v88dn89m80000gn/T/ipykernel_20169/3020659858.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Name': name, 'Address': address, 'Latitude': latitude, 'Longitude': longitude, 'Types': types, 'Price_level': price_level, 'Rating': rating, 'Reviews': reviews, 'Neighborhood': neighborhood}, ignore_index=True)
# /var/folders/xm/rzbs28zj73574d8v88dn89m80000gn/T/ipykernel_20169/3020659858.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Name': name, 'Address': address, 'Latitude': latitude, 'Longitude': longitude, 'Types': types, 'Price_level': price_level, 'Rating': rating, 'Reviews': reviews, 'Neighborhood': neighborhood}, ignore_index=True)
# /var/folders/xm/rzbs28zj73574d8v88dn89m80000gn/T/ipykernel_20169/3020659858.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Name': name, 'Address': address, 'Latitude': latitude, 'Longitude': longitude, 'Types': types, 'Price_level': price_level, 'Rating': rating, 'Reviews': reviews, 'Neighborhood': neighborhood}, ignore_index=True)
#                  Name                         Address   Latitude  Longitude  \
# 0           Cafe Lalo  201 West 83rd Street, New York  40.785953 -73.976661
# 1      Barnes & Noble         2289 Broadway, New York  40.786239 -73.978728
# 2    Peacefood Uptown  460 Amsterdam Avenue, New York  40.785275 -73.977012
# 3        French Roast         2340 Broadway, New York  40.787642 -73.976590
# 4           Starbucks         2394 Broadway, New York  40.789187 -73.975420
# ..                ...                             ...        ...        ...
# 177     La Parisienne         9 Maiden Lane, New York  40.709590 -74.009362
# 178         Starbucks       55 Broad Street, New York  40.705209 -74.011282
# 179     Pret A Manger           50 Broadway, New York  40.706211 -74.012451
# 180      Koyzina Kafe     62 William Street, New York  40.707058 -74.008441
# 181          Taz Cafe        54 Pine Street, New York  40.706807 -74.008525
#
#                                                  Types Price_level Rating  \
# 0       [cafe, food, point_of_interest, establishment]           2      4
# 1    [book_store, cafe, store, food, point_of_inter...           1    4.5
# 2    [cafe, bakery, store, restaurant, food, point_...           2    4.4
# 3    [cafe, store, restaurant, food, point_of_inter...           2    4.2
# 4    [cafe, store, restaurant, food, point_of_inter...           2      4
# ..                                                 ...         ...    ...
# 177  [restaurant, cafe, grocery_or_supermarket, bar...           2    4.6
# 178  [cafe, restaurant, food, point_of_interest, st...           2    4.2
# 179  [cafe, meal_takeaway, restaurant, food, point_...           2    4.1
# 180  [cafe, meal_takeaway, restaurant, food, point_...           1    4.3
# 181  [cafe, restaurant, food, point_of_interest, es...           2    3.8
#
#     Reviews       Neighborhood
# 0      1197      UpperWestSide
# 1      2698      UpperWestSide
# 2      1384      UpperWestSide
# 3      1021      UpperWestSide
# 4       372      UpperWestSide
# ..      ...                ...
# 177    1090  FinancialDistrict
# 178    1161  FinancialDistrict
# 179     406  FinancialDistrict
# 180     139  FinancialDistrict
# 181      75  FinancialDistrict
#
# [182 rows x 9 columns]

# %%
#write a function to round the rating
def round_rating(rating):
    if rating != '':
        try:
            num = float(rating)
            if num % 1 == 0.5:
                rounded_number = round(num + 0.1)
            else:
                rounded_number = round(num)
            return rounded_number
        except:
            return rating
    else:
        return rating

df['Rating'] = df['Rating'].apply(round_rating)
df
# Out:
#                  Name                         Address   Latitude  Longitude  \
# 0           Cafe Lalo  201 West 83rd Street, New York  40.785953 -73.976661
# 1      Barnes & Noble         2289 Broadway, New York  40.786239 -73.978728
# 2    Peacefood Uptown  460 Amsterdam Avenue, New York  40.785275 -73.977012
# 3        French Roast         2340 Broadway, New York  40.787642 -73.976590
# 4           Starbucks         2394 Broadway, New York  40.789187 -73.975420
# ..                ...                             ...        ...        ...
# 177     La Parisienne         9 Maiden Lane, New York  40.709590 -74.009362
# 178         Starbucks       55 Broad Street, New York  40.705209 -74.011282
# 179     Pret A Manger           50 Broadway, New York  40.706211 -74.012451
# 180      Koyzina Kafe     62 William Street, New York  40.707058 -74.008441
# 181          Taz Cafe        54 Pine Street, New York  40.706807 -74.008525
#
#                                                  Types Price_level Rating  \
# 0       [cafe, food, point_of_interest, establishment]           2      4
# 1    [book_store, cafe, store, food, point_of_inter...           1      5
# 2    [cafe, bakery, store, restaurant, food, point_...           2      4
# 3    [cafe, store, restaurant, food, point_of_inter...           2      4
# 4    [cafe, store, restaurant, food, point_of_inter...           2      4
# ..                                                 ...         ...    ...
# 177  [restaurant, cafe, grocery_or_supermarket, bar...           2      5
# 178  [cafe, restaurant, food, point_of_interest, st...           2      4
# 179  [cafe, meal_takeaway, restaurant, food, point_...           2      4
# 180  [cafe, meal_takeaway, restaurant, food, point_...           1      4
# 181  [cafe, restaurant, food, point_of_interest, es...           2      4
#
#     Reviews       Neighborhood
# 0      1197      UpperWestSide
# 1      2698      UpperWestSide
# 2      1384      UpperWestSide
# 3      1021      UpperWestSide
# 4       372      UpperWestSide
# ..      ...                ...
# 177    1090  FinancialDistrict
# 178    1161  FinancialDistrict
# 179     406  FinancialDistrict
# 180     139  FinancialDistrict
# 181      75  FinancialDistrict
#
# [182 rows x 9 columns]

# %%
#remove the duplicated cafes collected
df_clean = df.drop_duplicates(subset = ['Address'])
df_clean
# Out:
#                  Name                         Address   Latitude  Longitude  \
# 0           Cafe Lalo  201 West 83rd Street, New York  40.785953 -73.976661
# 1      Barnes & Noble         2289 Broadway, New York  40.786239 -73.978728
# 2    Peacefood Uptown  460 Amsterdam Avenue, New York  40.785275 -73.977012
# 3        French Roast         2340 Broadway, New York  40.787642 -73.976590
# 4           Starbucks         2394 Broadway, New York  40.789187 -73.975420
# ..                ...                             ...        ...        ...
# 177     La Parisienne         9 Maiden Lane, New York  40.709590 -74.009362
# 178         Starbucks       55 Broad Street, New York  40.705209 -74.011282
# 179     Pret A Manger           50 Broadway, New York  40.706211 -74.012451
# 180      Koyzina Kafe     62 William Street, New York  40.707058 -74.008441
# 181          Taz Cafe        54 Pine Street, New York  40.706807 -74.008525
#
#                                                  Types Price_level Rating  \
# 0       [cafe, food, point_of_interest, establishment]           2      4
# 1    [book_store, cafe, store, food, point_of_inter...           1      5
# 2    [cafe, bakery, store, restaurant, food, point_...           2      4
# 3    [cafe, store, restaurant, food, point_of_inter...           2      4
# 4    [cafe, store, restaurant, food, point_of_inter...           2      4
# ..                                                 ...         ...    ...
# 177  [restaurant, cafe, grocery_or_supermarket, bar...           2      5
# 178  [cafe, restaurant, food, point_of_interest, st...           2      4
# 179  [cafe, meal_takeaway, restaurant, food, point_...           2      4
# 180  [cafe, meal_takeaway, restaurant, food, point_...           1      4
# 181  [cafe, restaurant, food, point_of_interest, es...           2      4
#
#     Reviews       Neighborhood
# 0      1197      UpperWestSide
# 1      2698      UpperWestSide
# 2      1384      UpperWestSide
# 3      1021      UpperWestSide
# 4       372      UpperWestSide
# ..      ...                ...
# 177    1090  FinancialDistrict
# 178    1161  FinancialDistrict
# 179     406  FinancialDistrict
# 180     139  FinancialDistrict
# 181      75  FinancialDistrict
#
# [177 rows x 9 columns]

# %%
#replace all the NaN columns with a blank string
import numpy as np
df_clean.replace('', '', inplace=True)
df_clean
# Out:
# /var/folders/xm/rzbs28zj73574d8v88dn89m80000gn/T/ipykernel_20169/2982828667.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean.replace('', '', inplace=True)
#                  Name                         Address   Latitude  Longitude  \
# 0           Cafe Lalo  201 West 83rd Street, New York  40.785953 -73.976661
# 1      Barnes & Noble         2289 Broadway, New York  40.786239 -73.978728
# 2    Peacefood Uptown  460 Amsterdam Avenue, New York  40.785275 -73.977012
# 3        French Roast         2340 Broadway, New York  40.787642 -73.976590
# 4           Starbucks         2394 Broadway, New York  40.789187 -73.975420
# ..                ...                             ...        ...        ...
# 177     La Parisienne         9 Maiden Lane, New York  40.709590 -74.009362
# 178         Starbucks       55 Broad Street, New York  40.705209 -74.011282
# 179     Pret A Manger           50 Broadway, New York  40.706211 -74.012451
# 180      Koyzina Kafe     62 William Street, New York  40.707058 -74.008441
# 181          Taz Cafe        54 Pine Street, New York  40.706807 -74.008525
#
#                                                  Types Price_level Rating  \
# 0       [cafe, food, point_of_interest, establishment]           2      4
# 1    [book_store, cafe, store, food, point_of_inter...           1      5
# 2    [cafe, bakery, store, restaurant, food, point_...           2      4
# 3    [cafe, store, restaurant, food, point_of_inter...           2      4
# 4    [cafe, store, restaurant, food, point_of_inter...           2      4
# ..                                                 ...         ...    ...
# 177  [restaurant, cafe, grocery_or_supermarket, bar...           2      5
# 178  [cafe, restaurant, food, point_of_interest, st...           2      4
# 179  [cafe, meal_takeaway, restaurant, food, point_...           2      4
# 180  [cafe, meal_takeaway, restaurant, food, point_...           1      4
# 181  [cafe, restaurant, food, point_of_interest, es...           2      4
#
#     Reviews       Neighborhood
# 0      1197      UpperWestSide
# 1      2698      UpperWestSide
# 2      1384      UpperWestSide
# 3      1021      UpperWestSide
# 4       372      UpperWestSide
# ..      ...                ...
# 177    1090  FinancialDistrict
# 178    1161  FinancialDistrict
# 179     406  FinancialDistrict
# 180     139  FinancialDistrict
# 181      75  FinancialDistrict
#
# [177 rows x 9 columns]

# %%
#for all the blank character columns, we replaced blank with No Info
#for all the blank number columns, we replaced blank with -1
char_col = ['Name', 'Address', 'Types', 'Neighborhood']
num_col = ['Latitude', 'Longitude', 'Price_level', 'Rating', 'Reviews']

for col in char_col:
    df_clean[col].replace('', 'No Info', inplace=True)
    
for col in num_col:
    df_clean[col].replace('', -1, inplace=True)
    
df_clean
# Out:
# /var/folders/xm/rzbs28zj73574d8v88dn89m80000gn/T/ipykernel_20169/3996313706.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean[col].replace('', 'No Info', inplace=True)
# /var/folders/xm/rzbs28zj73574d8v88dn89m80000gn/T/ipykernel_20169/3996313706.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean[col].replace('', -1, inplace=True)
#                  Name                         Address   Latitude  Longitude  \
# 0           Cafe Lalo  201 West 83rd Street, New York  40.785953 -73.976661
# 1      Barnes & Noble         2289 Broadway, New York  40.786239 -73.978728
# 2    Peacefood Uptown  460 Amsterdam Avenue, New York  40.785275 -73.977012
# 3        French Roast         2340 Broadway, New York  40.787642 -73.976590
# 4           Starbucks         2394 Broadway, New York  40.789187 -73.975420
# ..                ...                             ...        ...        ...
# 177     La Parisienne         9 Maiden Lane, New York  40.709590 -74.009362
# 178         Starbucks       55 Broad Street, New York  40.705209 -74.011282
# 179     Pret A Manger           50 Broadway, New York  40.706211 -74.012451
# 180      Koyzina Kafe     62 William Street, New York  40.707058 -74.008441
# 181          Taz Cafe        54 Pine Street, New York  40.706807 -74.008525
#
#                                                  Types  Price_level  Rating  \
# 0       [cafe, food, point_of_interest, establishment]            2       4
# 1    [book_store, cafe, store, food, point_of_inter...            1       5
# 2    [cafe, bakery, store, restaurant, food, point_...            2       4
# 3    [cafe, store, restaurant, food, point_of_inter...            2       4
# 4    [cafe, store, restaurant, food, point_of_inter...            2       4
# ..                                                 ...          ...     ...
# 177  [restaurant, cafe, grocery_or_supermarket, bar...            2       5
# 178  [cafe, restaurant, food, point_of_interest, st...            2       4
# 179  [cafe, meal_takeaway, restaurant, food, point_...            2       4
# 180  [cafe, meal_takeaway, restaurant, food, point_...            1       4
# 181  [cafe, restaurant, food, point_of_interest, es...            2       4
#
#      Reviews       Neighborhood
# 0       1197      UpperWestSide
# 1       2698      UpperWestSide
# 2       1384      UpperWestSide
# 3       1021      UpperWestSide
# 4        372      UpperWestSide
# ..       ...                ...
# 177     1090  FinancialDistrict
# 178     1161  FinancialDistrict
# 179      406  FinancialDistrict
# 180      139  FinancialDistrict
# 181       75  FinancialDistrict
#
# [177 rows x 9 columns]

# %%
#output the dataframe into a json file
df_clean.to_json('cafes1.json', orient='records')

# %%
#output the dataframe into a csv file
df_clean.to_csv('cafes1.csv', index=False)

# %% [markdown]
# **Store the Data in PostgreSQL**

# %%
#install postgreSQL
# !pip install -U "psycopg[binary]"
# Out:
# Requirement already satisfied: psycopg[binary] in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (3.1.8)
# Requirement already satisfied: typing-extensions>=4.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from psycopg[binary]) (4.5.0)
# Requirement already satisfied: psycopg-binary<=3.1.8,>=3.1.6 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from psycopg[binary]) (3.1.8)

# %%
#connect to local host in postgreSQL
import psycopg, os

print('Connecting to the PostgreSQL database...')
conn = psycopg.connect(
    host="localhost",
    port='5432',
    dbname="postgres",
    user="postgres",
    password="123")
# Out:
# Connecting to the PostgreSQL database...

# %%
# create a cursor
cur = conn.cursor()

# %%
# execute a statement
print('PostgreSQL database version:')
cur.execute('SELECT version()')

# display the PostgreSQL database server version
db_version = cur.fetchone()
print(db_version)
# Out:
# PostgreSQL database version:
# ('PostgreSQL 15.1 (Debian 15.1-1.pgdg110+1) on x86_64-pc-linux-gnu, compiled by gcc (Debian 10.2.1-6) 10.2.1 20210110, 64-bit',)

# %%
# create a list of all the records
records2 = []
for index, row in df_clean.iterrows():
    name = row['Name']
    address = row['Address']
    latitude = row['Latitude']
    longitude = row['Longitude']
    types = row['Types']
    price_level = row['Price_level']
    rating = row['Rating']
    reviews = row['Reviews']
    neighborhood = row['Neighborhood']
    
    records2.append((name, address, latitude, longitude, types, price_level, rating, reviews, neighborhood))

# %%
# check the list
records2
# Out:
# [('Cafe Lalo',
#   '201 West 83rd Street, New York',
#   40.7859528,
#   -73.9766611,
#   ['cafe', 'food', 'point_of_interest', 'establishment'],
#   2,
#   4.0,
#   1198,
#   'Upper West Side'),
#  ('Barnes & Noble',
#   '2289 Broadway, New York',
#   40.7862392,
#   -73.9787281,
#   ['book_store',
#    'cafe',
#    'food',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   1,
#   4.5,
#   2693,
#   'Upper West Side'),
#  ('Peacefood Uptown',
#   '460 Amsterdam Avenue, New York',
#   40.785275,
#   -73.977012,
#   ['cafe',
#    'bakery',
#    'restaurant',
#    'food',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   2,
#   4.4,
#   1381,
#   'Upper West Side'),
#  ('French Roast',
#   '2340 Broadway, New York',
#   40.78764169999999,
#   -73.97659019999999,
#   ['cafe',
#    'restaurant',
#    'food',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   2,
#   4.2,
#   1017,
#   'Upper West Side'),
#  ('Starbucks',
#   '2394 Broadway, New York',
#   40.78918669999999,
#   -73.97542,
#   ['cafe',
#    'restaurant',
#    'food',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   2,
#   4.0,
#   371,
#   'Upper West Side'),
#  ('Joe Coffee Company',
#   '514 Columbus Avenue, New York',
#   40.7857679,
#   -73.9729782,
#   ['cafe', 'food', 'store', 'point_of_interest', 'establishment'],
#   1,
#   4.5,
#   380,
#   'Upper West Side'),
#  ('Starbucks',
#   '540 Columbus Avenue, New York',
#   40.786702,
#   -73.972251,
#   ['cafe',
#    'restaurant',
#    'food',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   2,
#   3.9,
#   626,
#   'Upper West Side'),
#  ('Matto Espresso',
#   '530 Columbus Avenue, New York',
#   40.7862598,
#   -73.97254339999999,
#   ['cafe', 'food', 'store', 'point_of_interest', 'establishment'],
#   1,
#   4.3,
#   146,
#   'Upper West Side'),
#  ('Flowers On The Park',
#   '520 Amsterdam Avenue, New York',
#   40.787309,
#   -73.97561999999999,
#   ['florist', 'cafe', 'food', 'store', 'point_of_interest', 'establishment'],
#   -1,
#   4.2,
#   82,
#   'Upper West Side'),
#  ('Uptown Poké',
#   '506 Amsterdam Avenue, New York',
#   40.7868084,
#   -73.976047,
#   ['cafe', 'restaurant', 'food', 'point_of_interest', 'establishment'],
#   1,
#   4.6,
#   337,
#   'Upper West Side'),
#  ("Dunkin'",
#   '535 Amsterdam Avenue Unit A, New York',
#   40.7874265,
#   -73.9749602,
#   ['cafe',
#    'bakery',
#    'meal_takeaway',
#    'restaurant',
#    'food',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   1,
#   3.4,
#   28,
#   'Upper West Side'),
#  ('Hawa Smoothies & Bubble Tea',
#   '495 Amsterdam Avenue, New York',
#   40.7861522,
#   -73.9757715,
#   ['cafe', 'restaurant', 'food', 'point_of_interest', 'establishment'],
#   -1,
#   4.4,
#   55,
#   'Upper West Side'),
#  ('Grain of rice',
#   '2350 Broadway, New York',
#   40.7878474,
#   -73.97643719999999,
#   ['cafe', 'food', 'point_of_interest', 'establishment'],
#   -1,
#   -1.0,
#   -1,
#   'Upper West Side'),
#  ('Amsterdam Cafe',
#   '481 Amsterdam Avenue, New York',
#   40.78574940000001,
#   -73.97616330000001,
#   ['cafe',
#    'meal_takeaway',
#    'restaurant',
#    'food',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   1,
#   4.2,
#   195,
#   'Upper West Side'),
#  ('Blank Street Coffee',
#   '2345 Broadway, New York',
#   40.7880912,
#   -73.9771422,
#   ['cafe', 'bakery', 'food', 'store', 'point_of_interest', 'establishment'],
#   -1,
#   5.0,
#   9,
#   'Upper West Side'),
#  ('Crossbar',
#   '250 West 86th Street, New York',
#   40.78842789999999,
#   -73.9771501,
#   ['restaurant',
#    'cafe',
#    'bakery',
#    'food',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   -1,
#   4.9,
#   44,
#   'Upper West Side'),
#  ('Chalait UWS',
#   '461 Amsterdam Avenue, New York',
#   40.785183,
#   -73.976552,
#   ['cafe', 'food', 'store', 'point_of_interest', 'establishment'],
#   2,
#   4.0,
#   123,
#   'Upper West Side'),
#  ('Barachou Upper West Side',
#   '449 Amsterdam Avenue Between 81st &, West 82nd Street, New York',
#   40.7847774,
#   -73.9769275,
#   ['bakery', 'cafe', 'food', 'store', 'point_of_interest', 'establishment'],
#   -1,
#   4.8,
#   212,
#   'Upper West Side'),
#  ('The Red Flame',
#   '67 West 44th Street, New York',
#   40.756077,
#   -73.982699,
#   ['meal_takeaway',
#    'cafe',
#    'restaurant',
#    'food',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   1,
#   4.1,
#   2381,
#   'Midtown'),
#  ('Gregorys Coffee',
#   '58 West 44th Street, New York',
#   40.7558258,
#   -73.9826362,
#   ['cafe', 'food', 'store', 'point_of_interest', 'establishment'],
#   2,
#   4.2,
#   746,
#   'Midtown'),
#  ('Lady M Cake Boutique - New York City',
#   '36 West 40th Street, New York',
#   40.7527864,
#   -73.98361489999999,
#   ['bakery', 'cafe', 'food', 'store', 'point_of_interest', 'establishment'],
#   3,
#   4.1,
#   914,
#   'Midtown'),
#  ('Starbucks',
#   '1500 Broadway, New York',
#   40.756694,
#   -73.985893,
#   ['cafe',
#    'restaurant',
#    'food',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   2,
#   4.0,
#   1845,
#   'Midtown'),
#  ('Venice Simplon Orient Espress',
#   'W. R. Grace Building, 1114 6th Avenue, New York',
#   40.75471719999999,
#   -73.98277449999999,
#   ['cafe', 'food', 'store', 'point_of_interest', 'establishment'],
#   -1,
#   -1.0,
#   -1,
#   'Midtown'),
#  ('Breads Bakery',
#   '1080 - 1090 6th Avenue, New York',
#   40.75456669999999,
#   -73.9839441,
#   ['bakery', 'cafe', 'food', 'store', 'point_of_interest', 'establishment'],
#   -1,
#   4.4,
#   205,
#   'Midtown'),
#  ('Wafels & Dinges',
#   '6th Avenue &, West 42nd Street, New York',
#   40.75454149999999,
#   -73.9840658,
#   ['cafe',
#    'restaurant',
#    'food',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   2,
#   4.4,
#   608,
#   'Midtown'),
#  ('Joe & The Juice',
#   '1114 6th Avenue, New York',
#   40.7545627,
#   -73.9829579,
#   ['meal_takeaway',
#    'cafe',
#    'restaurant',
#    'food',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   2,
#   3.6,
#   851,
#   'Midtown'),
#  ('Joe Coffee Company',
#   '55 West 40th St Structure #9, Kiosk #4, New York',
#   40.7534611,
#   -73.9843072,
#   ['cafe', 'food', 'store', 'point_of_interest', 'establishment'],
#   1,
#   4.3,
#   104,
#   'Midtown'),
#  ('Bryant Park Café',
#   '1065 6th Avenue #2400, New York',
#   40.7536881,
#   -73.98258969999999,
#   ['bar', 'cafe', 'restaurant', 'food', 'point_of_interest', 'establishment'],
#   -1,
#   4.3,
#   472,
#   'Midtown'),
#  ('La Colombe Coffee Roasters',
#   'Seven Bryant Park Building, 1045 6th Avenue, New York',
#   40.7535748,
#   -73.9855053,
#   ['cafe', 'food', 'store', 'point_of_interest', 'establishment'],
#   2,
#   4.4,
#   683,
#   'Midtown'),
#  ('Starbucks',
#   '1040 6th Avenue, New York',
#   40.75312399999999,
#   -73.985085,
#   ['cafe',
#    'restaurant',
#    'food',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   2,
#   3.9,
#   316,
#   'Midtown'),
#  ('Starbucks',
#   '1411 Broadway, New York',
#   40.754358,
#   -73.9872761,
#   ['cafe',
#    'restaurant',
#    'food',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   2,
#   3.9,
#   1081,
#   'Midtown'),
#  ("Dunkin'",
#   '42 West 39th Street #52, New York',
#   40.7523763,
#   -73.9844592,
#   ['bakery',
#    'meal_takeaway',
#    'cafe',
#    'restaurant',
#    'food',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   1,
#   3.6,
#   183,
#   'Midtown'),
#  ("Dunkin'",
#   '25 West 43rd Street, New York',
#   40.7549515,
#   -73.98179139999999,
#   ['bakery',
#    'meal_takeaway',
#    'cafe',
#    'restaurant',
#    'food',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   1,
#   3.9,
#   243,
#   'Midtown'),
#  ('EspressoWorks',
#   '37 West 39th Street, New York',
#   40.7526877,
#   -73.9842426,
#   ['cafe', 'food', 'point_of_interest', 'establishment'],
#   -1,
#   1.0,
#   1,
#   'Midtown'),
#  ('Starbucks',
#   '1101-1109 6th Avenue, New York',
#   40.7557119,
#   -73.9843001,
#   ['cafe',
#    'restaurant',
#    'food',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   2,
#   3.5,
#   353,
#   'Midtown'),
#  ('News Agency',
#   '1095 6th Avenue, New York',
#   40.75471659999999,
#   -73.98485819999999,
#   ['cafe', 'food', 'store', 'point_of_interest', 'establishment'],
#   -1,
#   4.2,
#   15,
#   'Midtown'),
#  ('Bluestone Lane Bryant Park Coffee Shop',
#   '1120 6th Avenue, New York',
#   40.75546979999999,
#   -73.9831779,
#   ['bar', 'cafe', 'food', 'store', 'point_of_interest', 'establishment'],
#   2,
#   4.1,
#   569,
#   'Midtown'),
#  ('Maman',
#   '114 West 41st Street, New York',
#   40.7544099,
#   -73.98560359999999,
#   ['cafe', 'food', 'store', 'point_of_interest', 'establishment'],
#   2,
#   4.1,
#   161,
#   'Midtown'),
#  ('Amish Market',
#   '731 9th Avenue, New York',
#   40.7633251,
#   -73.9894255,
#   ['supermarket',
#    'meal_takeaway',
#    'cafe',
#    'bakery',
#    'grocery_or_supermarket',
#    'restaurant',
#    'point_of_interest',
#    'food',
#    'store',
#    'establishment'],
#   2,
#   4.5,
#   728,
#   "Hell's Kitchen"),
#  ('The Jolly Goat Coffee Bar',
#   '515 West 47th Street, New York',
#   40.7632552,
#   -73.9940053,
#   ['cafe', 'point_of_interest', 'food', 'store', 'establishment'],
#   2,
#   4.5,
#   380,
#   "Hell's Kitchen"),
#  ('Vintner Market (Beer Cheese)',
#   '677 9th Avenue, New York',
#   40.7614718,
#   -73.9906944,
#   ['liquor_store',
#    'cafe',
#    'bar',
#    'point_of_interest',
#    'food',
#    'store',
#    'establishment'],
#   -1,
#   4.4,
#   133,
#   "Hell's Kitchen"),
#  ('Seasonal Grounds',
#   '417 West 47th Street, New York',
#   40.762066,
#   -73.99101449999999,
#   ['cafe', 'point_of_interest', 'food', 'establishment'],
#   -1,
#   -1.0,
#   -1,
#   "Hell's Kitchen"),
#  ("Dunkin'",
#   '693 9th Avenue, New York',
#   40.7621077,
#   -73.9902549,
#   ['meal_takeaway',
#    'cafe',
#    'bakery',
#    'restaurant',
#    'point_of_interest',
#    'food',
#    'store',
#    'establishment'],
#   1,
#   3.5,
#   240,
#   "Hell's Kitchen"),
#  ('ESCO CAFÉ',
#   '687 9th Avenue, New York',
#   40.7619194,
#   -73.9904178,
#   ['cafe', 'point_of_interest', 'food', 'establishment'],
#   1,
#   3.0,
#   1,
#   "Hell's Kitchen"),
#  ('Her Boba',
#   '457 West 50th Street, New York',
#   40.764666,
#   -73.9912643,
#   ['cafe',
#    'restaurant',
#    'point_of_interest',
#    'food',
#    'store',
#    'establishment'],
#   -1,
#   5.0,
#   27,
#   "Hell's Kitchen"),
#  ('JOOY TEA SHOPPE',
#   '653 9th Avenue, New York',
#   40.7608031,
#   -73.9912468,
#   ['cafe', 'point_of_interest', 'food', 'establishment'],
#   1,
#   4.5,
#   137,
#   "Hell's Kitchen"),
#  ('UT47 Manhattan',
#   '358 West 47th Street, New York',
#   40.7613127,
#   -73.9899748,
#   ['cafe',
#    'bakery',
#    'bar',
#    'restaurant',
#    'point_of_interest',
#    'food',
#    'store',
#    'establishment'],
#   -1,
#   4.6,
#   727,
#   "Hell's Kitchen"),
#  ('CoCo Fresh Tea & Juice',
#   '646 9th Avenue, New York',
#   40.76049099999999,
#   -73.9909066,
#   ['cafe', 'point_of_interest', 'food', 'establishment'],
#   1,
#   4.3,
#   91,
#   "Hell's Kitchen"),
#  ('Orwashers Bakery',
#   '308 East 78th Street, New York',
#   40.7722982,
#   -73.95494599999999,
#   ['bakery', 'cafe', 'food', 'store', 'point_of_interest', 'establishment'],
#   2,
#   4.5,
#   640,
#   'Upper East Side'),
#  ('Starbucks',
#   '245 East 80th Street, New York',
#   40.7743385,
#   -73.9547517,
#   ['cafe',
#    'restaurant',
#    'food',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   2,
#   4.0,
#   318,
#   'Upper East Side'),
#  ('Antonucci Cafe',
#   '170 East 81st Street, New York',
#   40.7756958,
#   -73.9569247,
#   ['cafe', 'bar', 'restaurant', 'food', 'point_of_interest', 'establishment'],
#   3,
#   4.5,
#   292,
#   'Upper East Side'),
#  ('Starbucks',
#   '1095 Lexington Avenue, New York',
#   40.7734469,
#   -73.95978749999999,
#   ['cafe',
#    'restaurant',
#    'food',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   2,
#   4.1,
#   650,
#   'Upper East Side'),
#  ('Hutch and Waldo Upper East',
#   '247 East 81st Street, New York',
#   40.774862,
#   -73.9542673,
#   ['cafe',
#    'bakery',
#    'restaurant',
#    'food',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   2,
#   4.4,
#   459,
#   'Upper East Side'),
#  ('Starbucks',
#   '1449 2nd Avenue, New York',
#   40.771087,
#   -73.956935,
#   ['cafe',
#    'restaurant',
#    'food',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   2,
#   3.8,
#   329,
#   'Upper East Side'),
#  ('Cafe Noi',
#   '1465 2nd Avenue, New York',
#   40.7716021,
#   -73.9565822,
#   ['cafe', 'bakery', 'food', 'store', 'point_of_interest', 'establishment'],
#   -1,
#   4.6,
#   230,
#   'Upper East Side'),
#  ('787 Coffee',
#   '228 East 80th Street, New York',
#   40.7742889,
#   -73.95563229999999,
#   ['cafe',
#    'bakery',
#    'restaurant',
#    'food',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   -1,
#   4.8,
#   472,
#   'Upper East Side'),
#  ('Birdbath Bakery JUICE',
#   '189 East 79th Street, New York',
#   40.7745368,
#   -73.95742800000001,
#   ['bakery', 'cafe', 'food', 'store', 'point_of_interest', 'establishment'],
#   -1,
#   -1.0,
#   -1,
#   'Upper East Side'),
#  ('Tozzo The Italian Coffee Shop',
#   '1491 2nd Avenue, New York',
#   40.7725225,
#   -73.9558404,
#   ['cafe', 'food', 'store', 'point_of_interest', 'establishment'],
#   -1,
#   5.0,
#   32,
#   'Upper East Side'),
#  ('Innocent Yesterday',
#   '252 B East 77th Street, New York',
#   40.77206,
#   -73.9564048,
#   ['cafe', 'bakery', 'food', 'store', 'point_of_interest', 'establishment'],
#   -1,
#   4.3,
#   182,
#   'Upper East Side'),
#  ('OLLIE’S TO GO - UES',
#   '307 East 77th Street, New York',
#   40.77201,
#   -73.955404,
#   ['meal_delivery',
#    'cafe',
#    'meal_takeaway',
#    'restaurant',
#    'food',
#    'point_of_interest',
#    'establishment'],
#   1,
#   3.8,
#   110,
#   'Upper East Side'),
#  ('Maman',
#   '1424 3rd Avenue, New York',
#   40.775544,
#   -73.9567155,
#   ['cafe',
#    'bakery',
#    'restaurant',
#    'food',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   2,
#   3.9,
#   243,
#   'Upper East Side'),
#  ('Angelina Paris Lexington',
#   '1121 Lexington Avenue, New York',
#   40.77414599999999,
#   -73.959346,
#   ['cafe', 'food', 'store', 'point_of_interest', 'establishment'],
#   -1,
#   5.0,
#   3,
#   'Upper East Side'),
#  ('Handcraft Coffee',
#   '151 East 77th Street, New York',
#   40.7736125,
#   -73.959497,
#   ['cafe', 'food', 'store', 'point_of_interest', 'establishment'],
#   2,
#   4.2,
#   242,
#   'Upper East Side'),
#  ('coffee gear',
#   '1569 2nd Avenue, New York',
#   40.7750657,
#   -73.9541558,
#   ['cafe', 'food', 'store', 'point_of_interest', 'establishment'],
#   -1,
#   -1.0,
#   -1,
#   'Upper East Side'),
#  ('Matto Espresso',
#   '1144 Lexington Avenue, New York',
#   40.7752667,
#   -73.958922,
#   ['cafe', 'food', 'store', 'point_of_interest', 'establishment'],
#   1,
#   4.4,
#   94,
#   'Upper East Side'),
#  ('Blank Street Coffee',
#   '1173 Lexington Avenue, New York',
#   40.7756985,
#   -73.9582274,
#   ['cafe', 'bakery', 'food', 'store', 'point_of_interest', 'establishment'],
#   -1,
#   3.9,
#   55,
#   'Upper East Side'),
#  ("Dunkin'",
#   '1104 Lexington Avenue, New York',
#   40.77392399999999,
#   -73.95989399999999,
#   ['cafe',
#    'meal_takeaway',
#    'bakery',
#    'restaurant',
#    'food',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   1,
#   3.8,
#   66,
#   'Upper East Side'),
#  ('Joe Coffee Company',
#   '405 West 23rd Street, New York',
#   40.746821,
#   -74.0014743,
#   ['cafe', 'store', 'food', 'point_of_interest', 'establishment'],
#   1,
#   4.3,
#   241,
#   'Chelsea'),
#  ('Starbucks',
#   '300 West 23rd Street, New York',
#   40.745218,
#   -73.99892960000001,
#   ['cafe',
#    'store',
#    'restaurant',
#    'food',
#    'point_of_interest',
#    'establishment'],
#   2,
#   3.8,
#   358,
#   'Chelsea'),
#  ('Sullivan Street Bakery and Pizza',
#   '236 9th Avenue, New York',
#   40.7473,
#   -74.0004556,
#   ['bakery',
#    'cafe',
#    'store',
#    'restaurant',
#    'food',
#    'point_of_interest',
#    'establishment'],
#   2,
#   4.4,
#   421,
#   'Chelsea'),
#  ('HARBS Chelsea',
#   '198 9th Avenue, New York',
#   40.745853,
#   -74.0015494,
#   ['cafe', 'bakery', 'store', 'food', 'point_of_interest', 'establishment'],
#   2,
#   4.5,
#   564,
#   'Chelsea'),
#  ("Dunkin'",
#   '243 9th Avenue, New York',
#   40.7477986,
#   -74.0007461,
#   ['bakery',
#    'cafe',
#    'meal_takeaway',
#    'store',
#    'restaurant',
#    'food',
#    'point_of_interest',
#    'establishment'],
#   1,
#   3.9,
#   64,
#   'Chelsea'),
#  ('Blank Street Coffee',
#   '172 9th Avenue, New York',
#   40.7449092,
#   -74.00214869999999,
#   ['bakery', 'cafe', 'store', 'food', 'point_of_interest', 'establishment'],
#   -1,
#   4.7,
#   45,
#   'Chelsea'),
#  ("Dunkin'",
#   '269 8th Avenue, New York',
#   40.7457658,
#   -73.99849379999999,
#   ['bakery',
#    'cafe',
#    'meal_takeaway',
#    'store',
#    'restaurant',
#    'food',
#    'point_of_interest',
#    'establishment'],
#   1,
#   3.6,
#   55,
#   'Chelsea'),
#  ('Café Moore',
#   '300 West 22nd Street, New York',
#   40.7446826,
#   -73.9994754,
#   ['cafe', 'food', 'point_of_interest', 'establishment'],
#   -1,
#   -1.0,
#   -1,
#   'Chelsea'),
#  ('Hawa Smoothies & Bubble Tea',
#   '247 8th Avenue, New York',
#   40.7449574,
#   -73.9990035,
#   ['cafe', 'health', 'store', 'food', 'point_of_interest', 'establishment'],
#   -1,
#   4.5,
#   112,
#   'Chelsea'),
#  ('HOUSE of WARIS Botanicals',
#   '463 West 24th Street, New York',
#   40.7483624,
#   -74.00338099999999,
#   ['cafe', 'store', 'food', 'point_of_interest', 'establishment'],
#   -1,
#   4.8,
#   8,
#   'Chelsea'),
#  ('Big Cup',
#   'United States',
#   40.7438581,
#   -74.0017155,
#   ['cafe', 'food', 'point_of_interest', 'establishment'],
#   -1,
#   -1.0,
#   -1,
#   'Chelsea'),
#  ('Dominique Ansel Bakery',
#   '189 Spring Street, New York',
#   40.7252509,
#   -74.0028734,
#   ['bakery', 'cafe', 'store', 'food', 'point_of_interest', 'establishment'],
#   2,
#   4.3,
#   6813,
#   'Soho'),
#  ('Ground Support Cafe',
#   '399 West Broadway, New York',
#   40.7242903,
#   -74.001961,
#   ['cafe', 'store', 'food', 'point_of_interest', 'establishment'],
#   2,
#   4.3,
#   746,
#   'Soho'),
#  ('La Colombe Coffee Roasters',
#   '154 Prince Street, New York',
#   40.72578060000001,
#   -74.0012273,
#   ['cafe', 'store', 'food', 'point_of_interest', 'establishment'],
#   2,
#   4.4,
#   212,
#   'Soho'),
#  ('L.A. Burdick Handmade Chocolates',
#   '156 Prince Street, New York',
#   40.7258666,
#   -74.0013032,
#   ['cafe', 'store', 'food', 'point_of_interest', 'establishment'],
#   2,
#   4.6,
#   348,
#   'Soho'),
#  ('Rapha New York',
#   '159 Prince Street, New York',
#   40.72603749999999,
#   -74.0012548,
#   ['clothing_store',
#    'bicycle_store',
#    'cafe',
#    'store',
#    'food',
#    'point_of_interest',
#    'establishment'],
#   -1,
#   4.3,
#   188,
#   'Soho'),
#  ('JOE & THE JUICE',
#   '161 Prince Street, New York',
#   40.726163,
#   -74.00121299999999,
#   ['cafe',
#    'meal_takeaway',
#    'store',
#    'restaurant',
#    'food',
#    'point_of_interest',
#    'establishment'],
#   2,
#   4.0,
#   220,
#   'Soho'),
#  ('Chobani SoHo',
#   '152 Prince Street, New York',
#   40.7258068,
#   -74.0011341,
#   ['cafe',
#    'store',
#    'restaurant',
#    'food',
#    'point_of_interest',
#    'establishment'],
#   2,
#   4.3,
#   939,
#   'Soho'),
#  ('Café OLED',
#   '386 West Broadway, New York',
#   40.7240423,
#   -74.00270429999999,
#   ['cafe', 'food', 'point_of_interest', 'establishment'],
#   -1,
#   -1.0,
#   -1,
#   'Soho'),
#  ('787 Coffee',
#   '72 Thompson Street, New York',
#   40.7244179,
#   -74.0029292,
#   ['cafe', 'store', 'food', 'point_of_interest', 'establishment'],
#   -1,
#   4.5,
#   100,
#   'Soho'),
#  ('Thompson Square Studios',
#   '54 Thompson Street 3rd floor, New York',
#   40.723844,
#   -74.003326,
#   ['cafe', 'bar', 'restaurant', 'food', 'point_of_interest', 'establishment'],
#   -1,
#   4.7,
#   12,
#   'Soho'),
#  ('MAKEDA NY',
#   '416 West Broadway, New York',
#   40.7250472,
#   -74.0018035,
#   ['cafe',
#    'clothing_store',
#    'store',
#    'food',
#    'point_of_interest',
#    'establishment'],
#   1,
#   4.7,
#   19,
#   'Soho'),
#  ('Dr Smood',
#   '470 Broome Street, New York',
#   40.7228891,
#   -74.0013006,
#   ['cafe',
#    'health',
#    'store',
#    'restaurant',
#    'food',
#    'point_of_interest',
#    'establishment'],
#   2,
#   3.7,
#   236,
#   'Soho'),
#  ('Old Fashion Café',
#   '110 Thompson Street, New York',
#   40.7257358,
#   -74.0017575,
#   ['restaurant', 'cafe', 'bar', 'food', 'point_of_interest', 'establishment'],
#   -1,
#   4.8,
#   84,
#   'Soho'),
#  ('Drip Drop Café, coffee shop',
#   '107 Thompson Street ST2, New York',
#   40.7258258,
#   -74.00204389999999,
#   ['art_gallery',
#    'cafe',
#    'store',
#    'restaurant',
#    'food',
#    'point_of_interest',
#    'establishment'],
#   1,
#   4.9,
#   203,
#   'Soho'),
#  ('YUBU SoHo',
#   '46 Grand Street, New York',
#   40.7226434,
#   -74.0039152,
#   ['cafe',
#    'store',
#    'restaurant',
#    'food',
#    'point_of_interest',
#    'establishment'],
#   -1,
#   4.8,
#   42,
#   'Soho'),
#  ('Sui Yoga & Café',
#   '180 6th Avenue, New York',
#   40.7259045,
#   -74.0036829,
#   ['cafe',
#    'gym',
#    'health',
#    'store',
#    'food',
#    'point_of_interest',
#    'establishment'],
#   -1,
#   4.9,
#   191,
#   'Soho'),
#  ('NowHere',
#   '40 Wooster Street First Floor, New York',
#   40.7222109,
#   -74.00251899999999,
#   ['art_gallery', 'cafe', 'food', 'point_of_interest', 'establishment'],
#   -1,
#   4.8,
#   13,
#   'Soho'),
#  ('Crispy Heaven',
#   '38 Grand Street, New York',
#   40.7227254,
#   -74.00420059999999,
#   ['bakery',
#    'cafe',
#    'bar',
#    'store',
#    'restaurant',
#    'food',
#    'point_of_interest',
#    'establishment'],
#   -1,
#   4.9,
#   162,
#   'Soho'),
#  ('Ademi Coffee and Tea',
#   '465 Broome Street, New York',
#   40.7223233,
#   -74.0011893,
#   ['cafe',
#    'bakery',
#    'store',
#    'restaurant',
#    'food',
#    'point_of_interest',
#    'establishment'],
#   -1,
#   4.0,
#   57,
#   'Soho'),
#  ('Matchaful',
#   '184 Prince Street, New York',
#   40.72629269999999,
#   -74.0021651,
#   ['cafe', 'food', 'point_of_interest', 'establishment'],
#   2,
#   4.5,
#   200,
#   'Soho'),
#  ('Golden Unicorn',
#   '18 East Broadway, New York',
#   40.7137006,
#   -73.997193,
#   ['cafe', 'bar', 'restaurant', 'food', 'point_of_interest', 'establishment'],
#   2,
#   3.9,
#   2710,
#   'Chinatown'),
#  ('Nom Wah Tea Parlor',
#   '13 Doyers Street, New York',
#   40.7144447,
#   -73.998254,
#   ['cafe', 'restaurant', 'food', 'point_of_interest', 'establishment'],
#   1,
#   4.3,
#   4050,
#   'Chinatown'),
#  ('Elevate',
#   '93 Bowery, New York',
#   40.7171058,
#   -73.9953219,
#   ['cafe', 'bar', 'restaurant', 'food', 'point_of_interest', 'establishment'],
#   2,
#   3.9,
#   7,
#   'Chinatown'),
#  ('ViVi Bubble Tea',
#   '49 Bayard Street, New York',
#   40.71519299999999,
#   -73.9974917,
#   ['cafe', 'food', 'point_of_interest', 'establishment'],
#   1,
#   4.1,
#   381,
#   'Chinatown'),
#  ('Yaya Tea',
#   '51 Chrystie Street, New York',
#   40.7162347,
#   -73.9949914,
#   ['cafe',
#    'grocery_or_supermarket',
#    'restaurant',
#    'store',
#    'food',
#    'point_of_interest',
#    'establishment'],
#   1,
#   4.5,
#   654,
#   'Chinatown'),
#  ('La Bella Ferrara',
#   '108 Mulberry Street, New York',
#   40.7173462,
#   -73.9982808,
#   ['bakery', 'cafe', 'store', 'food', 'point_of_interest', 'establishment'],
#   1,
#   4.5,
#   726,
#   'Chinatown'),
#  ('Cha Chan Tang',
#   '45 Mott Street, New York',
#   40.7153054,
#   -73.99896199999999,
#   ['cafe', 'restaurant', 'food', 'point_of_interest', 'establishment'],
#   1,
#   3.9,
#   754,
#   'Chinatown'),
#  ('Sweet Moment',
#   '106 Mott Street, New York',
#   40.71763,
#   -73.997147,
#   ['cafe',
#    'bakery',
#    'restaurant',
#    'store',
#    'food',
#    'point_of_interest',
#    'establishment'],
#   2,
#   4.5,
#   1049,
#   'Chinatown'),
#  ("Ten Ren's Tea Time",
#   '73 Mott Street, New York',
#   40.7163599,
#   -73.9982201,
#   ['cafe', 'restaurant', 'food', 'point_of_interest', 'establishment'],
#   1,
#   4.2,
#   417,
#   'Chinatown'),
#  ('Kung Fu Tea',
#   '73 Chrystie Street, New York',
#   40.7171189,
#   -73.9945616,
#   ['cafe', 'restaurant', 'food', 'point_of_interest', 'establishment'],
#   1,
#   4.1,
#   361,
#   'Chinatown'),
#  ('12 Corners',
#   '121 Mott Street, New York',
#   40.7180767,
#   -73.9971058,
#   ['bakery', 'cafe', 'store', 'food', 'point_of_interest', 'establishment'],
#   -1,
#   4.4,
#   100,
#   'Chinatown'),
#  ('Silk Road Cafe',
#   '30 Mott Street, New York',
#   40.7146964,
#   -73.99872069999999,
#   ['cafe', 'food', 'point_of_interest', 'establishment'],
#   1,
#   4.4,
#   246,
#   'Chinatown'),
#  ('Caffe Napoli',
#   '191 Hester Street, New York',
#   40.7182001,
#   -73.9978118,
#   ['cafe', 'bar', 'restaurant', 'food', 'point_of_interest', 'establishment'],
#   2,
#   4.0,
#   1914,
#   'Chinatown'),
#  ('Teado Tea Shop',
#   '145D Hester Street, New York',
#   40.71725289999999,
#   -73.9950257,
#   ['cafe', 'food', 'point_of_interest', 'establishment'],
#   1,
#   4.8,
#   493,
#   'Chinatown'),
#  ('Audrey Bakery and Cafe Inc',
#   '12 Chatham Square, New York',
#   40.7140439,
#   -73.9978445,
#   ['bakery', 'cafe', 'store', 'food', 'point_of_interest', 'establishment'],
#   1,
#   4.2,
#   176,
#   'Chinatown'),
#  ('Bake Culture',
#   '48 Bowery, New York',
#   40.71577509999999,
#   -73.9966627,
#   ['bakery', 'cafe', 'store', 'food', 'point_of_interest', 'establishment'],
#   1,
#   4.4,
#   260,
#   'Chinatown'),
#  ('Chun Yang Tea',
#   '26B Elizabeth Street, New York',
#   40.71615490000001,
#   -73.99704530000001,
#   ['cafe', 'food', 'point_of_interest', 'establishment'],
#   2,
#   4.3,
#   86,
#   'Chinatown'),
#  ('Kore Coffee',
#   '26A Elizabeth Street, New York',
#   40.7161808,
#   -73.9970865,
#   ['cafe', 'store', 'food', 'point_of_interest', 'establishment'],
#   -1,
#   4.8,
#   144,
#   'Chinatown'),
#  ('Karen Rutledge',
#   '155 Canal Street, New York',
#   40.7165657,
#   -73.9962765,
#   ['cafe', 'food', 'point_of_interest', 'establishment'],
#   -1,
#   -1.0,
#   -1,
#   'Chinatown'),
#  ('M Tea Chinatown',
#   '63 Bayard Street unit b, New York',
#   40.7153242,
#   -73.9980929,
#   ['cafe', 'food', 'point_of_interest', 'establishment'],
#   -1,
#   4.1,
#   29,
#   'Chinatown'),
#  ('Gnocco',
#   '337 East 10th Street, New York',
#   40.7271672,
#   -73.9802497,
#   ['cafe',
#    'bar',
#    'store',
#    'restaurant',
#    'food',
#    'point_of_interest',
#    'establishment'],
#   2,
#   4.4,
#   625,
#   'East Village'),
#  ('Gruppo NYC Thin Crust Pizza',
#   '98 Avenue B, New York',
#   40.7247688,
#   -73.98172439999999,
#   ['meal_delivery',
#    'cafe',
#    'bar',
#    'meal_takeaway',
#    'restaurant',
#    'food',
#    'point_of_interest',
#    'establishment'],
#   2,
#   4.6,
#   407,
#   'East Village'),
#  ('Starbucks',
#   '125 Saint Marks Place, New York',
#   40.72692259999999,
#   -73.9832362,
#   ['cafe',
#    'store',
#    'restaurant',
#    'food',
#    'point_of_interest',
#    'establishment'],
#   2,
#   3.8,
#   244,
#   'East Village'),
#  ('Ninth Street Espresso',
#   '341 East 10th Street, New York',
#   40.7270986,
#   -73.98008759999999,
#   ['cafe', 'store', 'food', 'point_of_interest', 'establishment'],
#   2,
#   4.3,
#   152,
#   'East Village'),
#  ("Ray's Candy Store",
#   '113 Avenue A, New York',
#   40.726249,
#   -73.983575,
#   ['cafe',
#    'store',
#    'restaurant',
#    'food',
#    'point_of_interest',
#    'establishment'],
#   1,
#   4.7,
#   904,
#   'East Village'),
#  ('Village creperie',
#   '445 East 9th Street, New York',
#   40.7274432,
#   -73.98282069999999,
#   ['cafe',
#    'store',
#    'restaurant',
#    'food',
#    'point_of_interest',
#    'establishment'],
#   1,
#   4.9,
#   117,
#   'East Village'),
#  ('Blank Street Coffee',
#   '149 Avenue A, New York',
#   40.72758950000001,
#   -73.9827045,
#   ['cafe', 'bakery', 'store', 'food', 'point_of_interest', 'establishment'],
#   -1,
#   4.0,
#   31,
#   'East Village'),
#  ('Murphy’s',
#   '440-A East 9th Street, New York',
#   40.7273006,
#   -73.9831177,
#   ['cafe', 'restaurant', 'food', 'point_of_interest', 'establishment'],
#   -1,
#   4.4,
#   128,
#   'East Village'),
#  ('La Fleur Café',
#   '437 East 9th Street, New York',
#   40.7276867,
#   -73.9831177,
#   ['cafe', 'food', 'health', 'point_of_interest', 'establishment'],
#   -1,
#   5.0,
#   47,
#   'East Village'),
#  ('Hekate Café & Elixir Lounge',
#   '167 Avenue B, New York',
#   40.72709939999999,
#   -73.97945610000001,
#   ['cafe', 'store', 'food', 'point_of_interest', 'establishment'],
#   -1,
#   4.7,
#   47,
#   'East Village'),
#  ('C&B',
#   '178 East 7th Street, New York',
#   40.7251413,
#   -73.98165569999999,
#   ['cafe', 'food', 'point_of_interest', 'establishment'],
#   2,
#   4.8,
#   332,
#   'East Village'),
#  ('787 Coffee',
#   '131 East 7th Street, New York',
#   40.7263237,
#   -73.9838523,
#   ['cafe', 'store', 'food', 'point_of_interest', 'establishment'],
#   1,
#   4.8,
#   499,
#   'East Village'),
#  ('Hi-Note',
#   '188 Avenue B, New York',
#   40.7279349,
#   -73.9793644,
#   ['bar', 'cafe', 'store', 'food', 'point_of_interest', 'establishment'],
#   -1,
#   4.9,
#   55,
#   'East Village'),
#  ('Thayer',
#   '99 Avenue B, New York',
#   40.72472119999999,
#   -73.9812783,
#   ['cafe', 'food', 'point_of_interest', 'establishment'],
#   -1,
#   4.9,
#   23,
#   'East Village'),
#  ('Kavasutra Kava Bar - 10th St',
#   '261 East 10th Street, New York',
#   40.72852049999999,
#   -73.983359,
#   ['cafe',
#    'night_club',
#    'bar',
#    'store',
#    'food',
#    'point_of_interest',
#    'establishment'],
#   2,
#   4.0,
#   404,
#   'East Village'),
#  ('All The Kings Horses Cafe',
#   '521 East 12th Street, New York',
#   40.72880720000001,
#   -73.9801906,
#   ['cafe',
#    'bar',
#    'store',
#    'restaurant',
#    'food',
#    'point_of_interest',
#    'establishment'],
#   -1,
#   4.7,
#   106,
#   'East Village'),
#  ('Lê Phin',
#   '259 East 10th Street, New York',
#   40.72850729999999,
#   -73.9834905,
#   ['cafe', 'store', 'food', 'point_of_interest', 'establishment'],
#   -1,
#   4.8,
#   151,
#   'East Village'),
#  ('dhom',
#   '505 East 12th Street, New York',
#   40.7290594,
#   -73.9809167,
#   ['cafe', 'bar', 'restaurant', 'food', 'point_of_interest', 'establishment'],
#   -1,
#   4.6,
#   75,
#   'East Village'),
#  ('Luz Cafe',
#   '97 Saint Marks Place, New York',
#   40.72747049999999,
#   -73.9845869,
#   ['cafe', 'food', 'point_of_interest', 'establishment'],
#   -1,
#   4.5,
#   35,
#   'East Village'),
#  ('Boris & Horton',
#   '195 Avenue A, New York',
#   40.7292874,
#   -73.98145629999999,
#   ['cafe', 'food', 'point_of_interest', 'establishment'],
#   -1,
#   4.7,
#   584,
#   'East Village'),
#  ('Buvette Gastrotheque',
#   'At the corner of Bleecker, 42 Grove Street, New York',
#   40.7326259,
#   -74.00432839999999,
#   ['cafe', 'bar', 'restaurant', 'food', 'point_of_interest', 'establishment'],
#   2,
#   4.4,
#   2924,
#   'Greenwich'),
#  ('Joe Coffee Company',
#   '141 Waverly Place, New York',
#   40.7332972,
#   -74.0005659,
#   ['cafe', 'food', 'point_of_interest', 'store', 'establishment'],
#   1,
#   4.5,
#   491,
#   'Greenwich'),
#  ("McNulty's Tea & Coffee Co",
#   '109 Christopher Street, New York',
#   40.73349899999999,
#   -74.005186,
#   ['cafe', 'food', 'point_of_interest', 'store', 'establishment'],
#   1,
#   4.8,
#   461,
#   'Greenwich'),
#  ('Jack’s Stir Brew Coffee',
#   '138 West 10th Street, New York',
#   40.7344539,
#   -74.00060979999999,
#   ['bakery',
#    'cafe',
#    'restaurant',
#    'food',
#    'point_of_interest',
#    'store',
#    'establishment'],
#   2,
#   4.0,
#   278,
#   'Greenwich'),
#  ("Marie's Crisis Café",
#   '59 Grove Street, New York',
#   40.733221,
#   -74.00340229999999,
#   ['cafe', 'bar', 'food', 'point_of_interest', 'establishment'],
#   1,
#   4.5,
#   959,
#   'Greenwich'),
#  ('Bantam Bagels',
#   '283 Bleecker Street, New York',
#   40.73196489999999,
#   -74.0032025,
#   ['bakery',
#    'cafe',
#    'meal_takeaway',
#    'restaurant',
#    'food',
#    'point_of_interest',
#    'store',
#    'establishment'],
#   1,
#   3.4,
#   194,
#   'Greenwich'),
#  ('Starbucks',
#   '72 Grove Street, New York',
#   40.7331755,
#   -74.002776,
#   ['cafe',
#    'restaurant',
#    'food',
#    'point_of_interest',
#    'store',
#    'establishment'],
#   2,
#   3.9,
#   515,
#   'Greenwich'),
#  ('Milk Bar',
#   '74 Christopher Street, New York',
#   40.7334552,
#   -74.0032794,
#   ['bakery', 'cafe', 'food', 'point_of_interest', 'store', 'establishment'],
#   2,
#   3.8,
#   234,
#   'Greenwich'),
#  ('Té Company',
#   '163 West 10th Street, New York',
#   40.7344879,
#   -74.00189859999999,
#   ['bakery', 'cafe', 'food', 'point_of_interest', 'store', 'establishment'],
#   -1,
#   4.8,
#   290,
#   'Greenwich'),
#  ('Partners Coffee',
#   '44 Charles Street, New York',
#   40.734916,
#   -74.0023197,
#   ['cafe', 'food', 'point_of_interest', 'store', 'establishment'],
#   2,
#   4.4,
#   394,
#   'Greenwich'),
#  ('ad hoc collective coffee + shoppe',
#   '13 Christopher Street, New York',
#   40.7340757,
#   -74.00048249999999,
#   ['cafe', 'food', 'point_of_interest', 'store', 'establishment'],
#   -1,
#   4.6,
#   247,
#   'Greenwich'),
#  ('Poke Rice',
#   '162 West 4th Street, New York',
#   40.731904,
#   -74.0013981,
#   ['cafe', 'restaurant', 'food', 'point_of_interest', 'establishment'],
#   1,
#   4.5,
#   314,
#   'Greenwich'),
#  ('Mah-Ze-Dahr',
#   '28 Greenwich Avenue, New York',
#   40.735039,
#   -74.0000184,
#   ['bakery',
#    'cafe',
#    'restaurant',
#    'food',
#    'point_of_interest',
#    'store',
#    'establishment'],
#   2,
#   4.6,
#   587,
#   'Greenwich'),
#  ("Dunkin'",
#   '75 Christopher Street, New York',
#   40.7336968,
#   -74.0032775,
#   ['bakery',
#    'cafe',
#    'meal_takeaway',
#    'restaurant',
#    'food',
#    'point_of_interest',
#    'store',
#    'establishment'],
#   1,
#   3.9,
#   92,
#   'Greenwich'),
#  ('St Jardim',
#   '183 West 10th Street, New York',
#   40.7343755,
#   -74.00284789999999,
#   ['cafe',
#    'bar',
#    'restaurant',
#    'food',
#    'point_of_interest',
#    'store',
#    'establishment'],
#   -1,
#   4.7,
#   135,
#   'Greenwich'),
#  ('787 Coffee',
#   '208 West 10th Street, New York',
#   40.7338774,
#   -74.0041154,
#   ['cafe', 'food', 'point_of_interest', 'store', 'establishment'],
#   -1,
#   5.0,
#   188,
#   'Greenwich'),
#  ('Hungry Ghost Coffee',
#   '315 Bleecker Street, New York',
#   40.7328889,
#   -74.0038452,
#   ['cafe', 'food', 'point_of_interest', 'establishment'],
#   2,
#   3.9,
#   83,
#   'Greenwich'),
#  ('Do Not Feed Alligators',
#   '337 Bleecker Street, New York',
#   40.7336939,
#   -74.0042366,
#   ['book_store',
#    'cafe',
#    'bar',
#    'food',
#    'point_of_interest',
#    'store',
#    'establishment'],
#   -1,
#   4.4,
#   76,
#   'Greenwich'),
#  ('Julietta Gelato Cafè',
#   '335 Bleecker Street, New York',
#   40.7336439,
#   -74.0042752,
#   ['cafe', 'food', 'point_of_interest', 'store', 'establishment'],
#   -1,
#   4.5,
#   118,
#   'Greenwich'),
#  ('Joji Rooftop',
#   '62 Charles Street, New York',
#   40.7348316,
#   -74.0029255,
#   ['cafe', 'food', 'point_of_interest', 'establishment'],
#   -1,
#   3.0,
#   2,
#   'Greenwich'),
#  ("McDonald's",
#   '160 Broadway, New York',
#   40.7094789,
#   -74.01003639999999,
#   ['cafe',
#    'store',
#    'restaurant',
#    'food',
#    'point_of_interest',
#    'establishment'],
#   1,
#   3.8,
#   5130,
#   'Financial District'),
#  ("Dunkin'",
#   '19 Rector Street, New York',
#   40.7079962,
#   -74.0139006,
#   ['bakery',
#    'cafe',
#    'meal_takeaway',
#    'store',
#    'restaurant',
#    'food',
#    'point_of_interest',
#    'establishment'],
#   1,
#   3.8,
#   275,
#   'Financial District'),
#  ('Bean & Bean Wall St',
#   '71 Broadway, New York',
#   40.7073176,
#   -74.0124258,
#   ['cafe',
#    'meal_takeaway',
#    'store',
#    'restaurant',
#    'food',
#    'point_of_interest',
#    'establishment'],
#   2,
#   4.4,
#   356,
#   'Financial District'),
#  ("Dunkin'",
#   '50 Pine Street, New York',
#   40.70684920000001,
#   -74.0086671,
#   ['bakery',
#    'cafe',
#    'meal_takeaway',
#    'store',
#    'restaurant',
#    'food',
#    'point_of_interest',
#    'establishment'],
#   1,
#   3.6,
#   128,
#   'Financial District'),
#  ('Starbucks',
#   '115 Broadway, New York',
#   40.708758,
#   -74.011055,
#   ['cafe',
#    'store',
#    'restaurant',
#    'food',
#    'point_of_interest',
#    'establishment'],
#   2,
#   3.8,
#   469,
#   'Financial District'),
#  ('Schimenti construction',
#   '14 Wall Street, New York',
#   40.7075827,
#   -74.0108283,
#   ['cafe', 'food', 'point_of_interest', 'establishment'],
#   -1,
#   -1.0,
#   -1,
#   'Financial District'),
#  ('JOE & THE JUICE',
#   '40 Broad Street, New York',
#   40.7060825,
#   -74.0115872,
#   ['cafe',
#    'meal_takeaway',
#    'store',
#    'restaurant',
#    'food',
#    'point_of_interest',
#    'establishment'],
#   2,
#   3.9,
#   198,
#   'Financial District'),
#  ('Gregorys Coffee',
#   '42 Broadway, New York',
#   40.705974,
#   -74.01261459999999,
#   ['cafe', 'store', 'food', 'point_of_interest', 'establishment'],
#   2,
#   4.1,
#   307,
#   'Financial District'),
#  ("Dunkin'",
#   '49 Nassau Street, New York',
#   40.7089375,
#   -74.00926539999999,
#   ['bakery',
#    'cafe',
#    'meal_takeaway',
#    'store',
#    'restaurant',
#    'food',
#    'point_of_interest',
#    'establishment'],
#   1,
#   3.9,
#   72,
#   'Financial District'),
#  ('Open Market',
#   '15 William Street, New York',
#   40.705309,
#   -74.010183,
#   ['convenience_store',
#    'cafe',
#    'grocery_or_supermarket',
#    'health',
#    'store',
#    'restaurant',
#    'food',
#    'point_of_interest',
#    'establishment'],
#   2,
#   4.2,
#   531,
#   'Financial District'),
#  ("Dunkin'",
#   '2 Cortlandt Street, New York',
#   40.71001529999999,
#   -74.0101766,
#   ['bakery',
#    'cafe',
#    'meal_takeaway',
#    'store',
#    'restaurant',
#    'food',
#    'point_of_interest',
#    'establishment'],
#   1,
#   3.8,
#   71,
#   'Financial District'),
#  ("Dunkin'",
#   '33 Beaver Street, New York',
#   40.7051018,
#   -74.0120718,
#   ['bakery',
#    'cafe',
#    'meal_takeaway',
#    'store',
#    'restaurant',
#    'food',
#    'point_of_interest',
#    'establishment'],
#   1,
#   3.9,
#   200,
#   'Financial District'),
#  ('Metropolitan Coffee Company',
#   '30 Broad Street, New York',
#   40.7061111,
#   -74.0115419,
#   ['cafe', 'store', 'food', 'point_of_interest', 'establishment'],
#   -1,
#   1.0,
#   1,
#   'Financial District'),
#  ('La Parisienne',
#   '9 Maiden Lane, New York',
#   40.70959,
#   -74.009362,
#   ['restaurant',
#    'cafe',
#    'grocery_or_supermarket',
#    'store',
#    'bar',
#    'food',
#    'point_of_interest',
#    'establishment'],
#   2,
#   4.6,
#   1073,
#   'Financial District'),
#  ('Starbucks',
#   '55 Broad Street, New York',
#   40.7052088,
#   -74.0112817,
#   ['cafe',
#    'store',
#    'restaurant',
#    'food',
#    'point_of_interest',
#    'establishment'],
#   2,
#   4.2,
#   1161,
#   'Financial District'),
#  ('Koyzina Kafe',
#   '62 William Street, New York',
#   40.707058,
#   -74.00844099999999,
#   ['cafe',
#    'meal_takeaway',
#    'restaurant',
#    'food',
#    'point_of_interest',
#    'establishment'],
#   1,
#   4.3,
#   139,
#   'Financial District'),
#  ('Taz Cafe',
#   '54 Pine Street, New York',
#   40.706807,
#   -74.00852499999999,
#   ['cafe', 'restaurant', 'food', 'point_of_interest', 'establishment'],
#   2,
#   3.8,
#   75,
#   'Financial District')]

# %%
#create cafes table in postgreSQL

createCmd = """CREATE TABLE cafe8 (
                    Name varchar(255),
                    Address varchar(255),
                    Latitude numeric,
                    Longitude numeric,
                    Types varchar(255),
                    Price_level integer,
                    Rating float,
                    Reviews integer,
                    Neighborhood varchar(255),
                    PRIMARY KEY (Address)  
                );"""

#NOTE: we will prob want to change the primary key to (name, places_id) since not every place has an address listed.

cur.execute(createCmd)

#insert data row by row (normal insert df.iterrows)
#save api into file form and import into sql

conn.commit()

# %%
#insert values into the cafe table
insertCmd = "INSERT INTO cafe8 VALUES (%s,%s,%s,%s,%s,%s,%s,%s,%s)"

# %%
cur.executemany(insertCmd, records2)

# %%
conn.commit()

# %%
cur.execute('DROP TABLE IF EXISTS cafe')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/xm/rzbs28zj73574d8v88dn89m80000gn/T/ipykernel_79837/818771807.py in <module>
# ----> 1 cur.execute('DROP TABLE IF EXISTS cafes')
#
# ~/opt/anaconda3/lib/python3.9/site-packages/psycopg/cursor.py in execute(self, query, params, prepare, binary)
#     717         try:
#     718             with self._conn.lock:
# --> 719                 self._conn.wait(
#     720                     self._execute_gen(query, params, prepare=prepare, binary=binary)
#     721                 )
#
# ~/opt/anaconda3/lib/python3.9/site-packages/psycopg/connection.py in wait(self, gen, timeout)
#     955         """
#     956         try:
# --> 957             return waiting.wait(gen, self.pgconn.socket, timeout=timeout)
#     958         except KeyboardInterrupt:
#     959             # On Ctrl-C, try to cancel the query in the server, otherwise
#
# psycopg_binary/_psycopg/waiting.pyx in psycopg_binary._psycopg.wait_c()
#
# KeyboardInterrupt:

# %%
import csv
# execute a SELECT query to retrieve data from a table
cur.execute("SELECT * FROM cafe8")

# fetch all rows as a list of tuples
rows = cur.fetchall()

# close the cursor and connection
cur.close()
conn.close()

# write the rows to a CSV file
with open('cafe_data.csv', 'w', newline='') as f:
    writer = csv.writer(f)
    writer.writerow(['Name', 'Address', 'Latitude', 'Longitude', 'Types', 'Price_level', 'Rating', 'Reviews', 'Neighborhood'])
    writer.writerows(rows)

# %% [markdown]
# **Connect SQL database to Spark**

# %%
# !pip install -U pyspark
from pyspark.sql import SparkSession
# Out:
# Requirement already satisfied: pyspark in /Users/PinkyPig/opt/anaconda3/lib/python3.9/site-packages (3.3.2)
# Collecting pyspark
#   Downloading pyspark-3.4.0.tar.gz (310.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 310.8/310.8 MB 1.3 MB/s eta 0:00:0000:0100:03
#   Preparing metadata (setup.py) ... done
# Collecting py4j==0.10.9.7
#   Downloading py4j-0.10.9.7-py2.py3-none-any.whl (200 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 200.5/200.5 kB 2.0 MB/s eta 0:00:00a 0:00:01
# Building wheels for collected packages: pyspark
#   Building wheel for pyspark (setup.py) ... done
#   Created wheel for pyspark: filename=pyspark-3.4.0-py2.py3-none-any.whl size=311317131 sha256=f40b88382ec0f91cf2cea63ff29302dbf9cd165a5e32df94493085d12c070808
#   Stored in directory: /Users/PinkyPig/Library/Caches/pip/wheels/9f/34/a4/159aa12d0a510d5ff7c8f0220abbea42e5d81ecf588c4fd884
# Successfully built pyspark
# Installing collected packages: py4j, pyspark
#   Attempting uninstall: py4j
#     Found existing installation: py4j 0.10.9.5
#     Uninstalling py4j-0.10.9.5:
#       Successfully uninstalled py4j-0.10.9.5
#   Attempting uninstall: pyspark
#     Found existing installation: pyspark 3.3.2
#     Uninstalling pyspark-3.3.2:
#       Successfully uninstalled pyspark-3.3.2
# Successfully installed py4j-0.10.9.7 pyspark-3.4.0

# %% [markdown]
# **Initiate and Configure Spark Session**

# %%
import os
import sys
os.environ['PYSPARK_PYTHON'] = sys.executable
os.environ['PYSPARK_DRIVER_PYTHON'] = sys.executable

# %%
from pyspark.sql import SparkSession
from pyspark import SparkContext, SparkConf
from pyspark.sql import SQLContext

spark = SparkSession.builder.getOrCreate()
sc = spark.sparkContext

print("Using Apache Spark Version", spark.version)
# Out:
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 23/04/18 16:31:55 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# Using Apache Spark Version 3.4.0

# %% [markdown]
# **Upload CSV File and Creating Spark Dataframe**

# %%
from pyspark.sql import SparkSession
import pandas as pd
from pyspark.sql.types import StructType, StructField, StringType, IntegerType, DoubleType
filecontents = pd.read_csv('cafes1.csv')

schema = StructType([
    StructField("Name", StringType(), True),
    StructField("Address", StringType(), True),
    StructField("Latitude", DoubleType(), True),
    StructField("Longitude", DoubleType(), True), 
    StructField("Types", StringType(), True), 
    StructField("Price_level", IntegerType(), True), 
    StructField("Rating", IntegerType(), True), 
    StructField("Reviews", IntegerType(), True), 
    StructField("Neighborhood", StringType(), True),  
])

sparkDF=spark.createDataFrame(filecontents, schema) 
sparkDF.printSchema()
sparkDF.show()
# Out:
# [Stage 0:===========================================================(1 + 0) / 1]
# +-------------------+--------------------+----------+-----------+--------------------+-----------+------+-------+---------------+
# |               Name|             Address|  Latitude|  Longitude|               Types|Price_level|Rating|Reviews|   Neighborhood|
# +-------------------+--------------------+----------+-----------+--------------------+-----------+------+-------+---------------+
# |          Cafe Lalo|201 West 83rd Str...|40.7859528|-73.9766611|{cafe,food,point_...|          2|   4.0|   1198|Upper West Side|
# |     Barnes & Noble|2289 Broadway, Ne...|40.7862392|-73.9787281|{book_store,cafe,...|          1|   4.5|   2693|Upper West Side|
# |   Peacefood Uptown|460 Amsterdam Ave...| 40.785275| -73.977012|{cafe,bakery,rest...|          2|   4.4|   1381|Upper West Side|
# |       French Roast|2340 Broadway, Ne...|40.7876417|-73.9765902|{cafe,restaurant,...|          2|   4.2|   1017|Upper West Side|
# |          Starbucks|2394 Broadway, Ne...|40.7891867|  -73.97542|{cafe,restaurant,...|          2|   4.0|    371|Upper West Side|
# | Joe Coffee Company|514 Columbus Aven...|40.7857679|-73.9729782|{cafe,food,store,...|          1|   4.5|    380|Upper West Side|
# |          Starbucks|540 Columbus Aven...| 40.786702| -73.972251|{cafe,restaurant,...|          2|   3.9|    626|Upper West Side|
# |     Matto Espresso|530 Columbus Aven...|40.7862598|-73.9725434|{cafe,food,store,...|          1|   4.3|    146|Upper West Side|
# |Flowers On The Park|520 Amsterdam Ave...| 40.787309|  -73.97562|{florist,cafe,foo...|         -1|   4.2|     82|Upper West Side|
# |        Uptown Poké|506 Amsterdam Ave...|40.7868084| -73.976047|{cafe,restaurant,...|          1|   4.6|    337|Upper West Side|
# +-------------------+--------------------+----------+-----------+--------------------+-----------+------+-------+---------------+
# only showing top 10 rows

# %% [markdown]
# **Filter and Tokenize 'Types' Column**

# %%
from pyspark.sql.functions import col, lower, regexp_replace
from pyspark.ml.feature import HashingTF, IDF, Tokenizer
from pyspark.ml.feature import VectorAssembler
from pyspark.ml import Pipeline
from pyspark.sql.types import StructType,StructType, StringType, IntegerType

# %%
from pyspark.ml.feature import RegexTokenizer, StopWordsRemover, Word2Vec 
# types
regexTokFilter = RegexTokenizer(gaps = False, pattern = '\w+', inputCol = 'Types', outputCol = 'tokens_types')
sparkDF_tok= regexTokFilter.transform(sparkDF)

# %% [markdown]
# **Printing Tokenized Dataframe**

# %%
sparkDF_tok.printSchema()

# %%
sparkDF_tok['Types','tokens_types'].show()

# %% [markdown]
# **Creating Similarity Model with Word Vector**

# %%
word2vec_type = Word2Vec(vectorSize = 500, minCount = 1, inputCol = 'tokens_types', outputCol = 'wordvectors_type')
model_type = word2vec_type.fit(sparkDF_tok)
wordvectors_type = model_type.transform(sparkDF_tok)

# %%
sparkDF_wv = wordvectors_type.select('Name','Address','Latitude','Longitude','Types','Price_level','Rating',
                                         'Reviews','Neighborhood','tokens_types','wordvectors_type').rdd.toDF()
sparkDF_wv.show()

# %%
sparkDF_wv['Types','tokens_types','wordvectors_type'].show()

# %%
sparkDF_wv_final = sparkDF_wv.collect()
print(sparkDF_wv_final)

# %%
synonyms = model_type.findSynonyms("grocery_or_supermarket",10)  
synonyms.show()

# %% [markdown]
# **Creating Search Engine through Flask**

# %%
from flask import Flask, request, jsonify, redirect, url_for, render_template
import numpy as np

app = Flask("JSON_OUTPUT")

@app.route('/')
def form():
    return render_template('moreedits.html')
        
@app.route('/submit', methods=['GET','POST'])
def submit():
    if request.method == 'POST':
        types_user = request.form['q']
        price_level_user = request.form['price_level']
        neighborhood_user = request.form['neighborhoods']
        rating_user = request.form['rating']
        
        def cossim(v1, v2):
            dot_product = np.sum(v1 * v2)
            mag_v1 = np.sqrt(np.sum(np.power(v1, 2)))
            mag_v2 = np.sqrt(np.sum(np.power(v2, 2)))
            return dot_product / (mag_v1 * mag_v2 + 0.1)

        query_txt = types_user
        query_df = sc.parallelize([(1,query_txt)]).toDF(['index','Types'])
        query_tok = regexTokFilter.transform(query_df)
        query_vec = model_type.transform(query_tok)
        query_vec = query_vec.select('wordvectors_type').collect()[0][0]
        
        sim_rdd = sc.parallelize((i[0],i[1], i[2],i[3],i[4],i[5],i[6],float(cossim(query_vec, i[7])), i[8]) for i in sparkDF_wv_final)
        sim_df = spark.createDataFrame(sim_rdd).\
            withColumnRenamed('_1', 'Name').\
            withColumnRenamed('_2', 'Address').\
            withColumnRenamed('_3', 'Latitude').\
            withColumnRenamed('_4', 'Longitude').\
            withColumnRenamed('_5', 'Types').\
            withColumnRenamed('_6', 'Price_level').\
            withColumnRenamed('_7', 'Rating').\
            withColumnRenamed('_8', 'Similarity').\
            withColumnRenamed('_9', 'Neighborhood').\
            orderBy("Similarity", ascending=False)

    
    pandas_df = sim_df.toPandas()
    df_filtered = pandas_df[pandas_df['Price_level'] == int(price_level_user)]
    df_filtered1 = df_filtered[df_filtered['Rating'] == int(rating_user)]
    df_filtered2 = df_filtered1[df_filtered1['Neighborhood'] == neighborhood_user]
    html_table = df_filtered2.head(10).to_html(classes='table')
    return render_template('onlytable.html', table=html_table)

@app.route('/output')
def output():
    # render the output HTML page
    return render_template('onlytable.html',table=processed_data)

app.run(host='localhost', port=7030)
